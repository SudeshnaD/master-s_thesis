# %%
import pickle
with open('aspect_file50.pkl', 'rb') as f:
    file=pickle.load(f)
print(file)
# Out:
# {0: ['hassidic', 'subsect', 'literati', 'danelaw', 'se5', 'cattery', 'robertsbridge', 'chav', 'mutli', 'hte', 'shite', 'luddite', 'rasta', 'caucasian', 'pleasantest', 'nightjar', 'standart', 'youngish', 'skanky', 'toff', 'gumtree', 'aristocratic', 'northerner', 'punjabi', 'handiest', 'neals', 'skank', 'expat', 'tadgh', 'druggies', 'e9', 'abit', 'bedsit', 'inbetween', 'stollen', 'generalisation', 'e17', 'thameside', 'btw', 'reveler', 'straggler', 'ified', 'chavs', 'pushchair', 'weirdo', 'somalian', 'carib', 'goth', 'characterless', 'lsb', 'rushbrooke', 'cr2', 'independant', 'londinium', 'youd', 'haved', 'truely', 'sm1', 'haha', 'fullfill', 'bedroomed', 'boho', 'tranport', 'nobility', 'haa', 'serf', 'portugese', 'e8', 'youre', 'saxon', 'cemetary', 'byt', 'dialect', 'n14', 'microbrewery', 'swt', 'westminister', 'flightpath', 'shaftsbury', 'westend', 'yh', 'trialists', 'grotty', 'onr', 'byfleet', 'hipster', 'uca', 'outskirt', 'ghanian', 'bohemian', 'unislamic', 'succesful', 'daresay', 'k
# ...
