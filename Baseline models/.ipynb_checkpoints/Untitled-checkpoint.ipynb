# %%
from sklearn.decomposition import NMF
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
import numpy as np

# %%
corpus=r'C:\Users\Sudeshna Dasgupta\Documents\Thesis_GuidedResearch\thesis\Aspect Extraction\Baseline models\preprocessed_data\sentihood\train.txt'

# %%
corpus_text=[]
with open(corpus, 'r') as f:
    corpus_text=f.readlines()

# %%
corpus_text
# Out:
# ['location1 transforming price go\n',
#  'along location1 lot electronics shop independent one\n',
#  'location1 ten min direct tube location2\n',
#  'another option location1 central ton club bar within walking distance\n',
#  'best bet around location2 location1 area northwest corner really nice\n',
#  'central london based taxi mostly refuse fare suburban area like location1\n',
#  'go looking place like location1 rough area really want live\n',
#  'everyone location1 black bangladeshi\n',
#  'god sake move location1 horrible\n',
#  'dont like location1\n',
#  'friend living location1 love\n',
#  'heard location1 place live london\n',
#  'liv location1 location2 place lot violence happens wiv gang\n',
#  'live location1 cant say recommend\n',
#  'live location1 11 year problem\n',
#  'live location1 great access transport great pub beautiful house area good school\n',
#  'lived location1 ten year rough sooo close centre town cheap\n',
#  'lived location1 month adored\n',
#  'really like location1 lived month lot fun\n',
#  'really love location1 beautiful house conservation area broadway market tube\n',
#  'think location1 best bet\n',
#  'would rather live location1\n',
#  'would say either location1 location2 money\n',
#  'would suggest location1 pretty good area\n',
#  'stay away location1\n',
#  'never lived location1 know reasonably well would say ok place live\n',
#  'money would live near location1\n',
#  'thinking south london try location1\n',
#  'would worth looking around location1\n',
#  'location1 traditionally wealthy area fact amongst poorest area entire uk\n',
#  'location1 pronounced gren itch lovely town part expensive\n',
#  'location1 aint bad\n',
#  'location1 location2 better area west southwest london\n',
#  'location1 location2 area nice think\n',
#  'location1 attract many immigrant cheaper\n',
#  'location1 cheap lovely people\n',
#  'location1 even lovely big park go walk etc good luck\n',
#  'location1 large jewish population\n',
#  'location1 become bit market recent year bad place\n',
#  'location1 location1 might suitable 30 minute central london\n',
#  'location1 good place live major rail station\n',
#  'location1 mainly indian area safe lot family child\n',
#  'location1 nice suburb location1\n',
#  'location1 safe area see lot tourist sexy lady\n',
#  'location1 trendy edgy area lot live music venue\n',
#  'location1 druggies tourist\n',
#  'location1 good\n',
#  'location1 good shabby\n',
#  'location1 east london one affordable part london live\n',
#  'location1 okay\n',
#  'location1 lovely location2 others said\n',
#  'location1 expensive london good local school\n',
#  'location1 expensive lot shop cafe etc offer\n',
#  'location1 dangerous ugly jumble concrete character\n',
#  'location1 one affluent area offer much nicer environment live south river\n',
#  'location1 one ruffest place london\n',
#  'location1 pretty bad stabbings mugging general filth place\n',
#  'location1 quite nice area\n',
#  'location1 safe hear noisy drunk anywhere\n',
#  'location1 best long shot\n',
#  'location1 place love\n',
#  'location1 worth visit going spring summer time\n',
#  'location1 bad\n',
#  'location1 bad vibrant diverse place crime location2\n',
#  'location1 would pretty good laid back spot mostly local\n',
#  'location1 hole\n',
#  'location1 lovely town expensive\n',
#  'location1 central area close location1\n',
#  'location1 nice quite quiet\n',
#  'location2 location1 cheapest talking real world\n',
#  'london diverse racist area live location1 never problem\n',
#  'lot better area expensive definitely location1\n',
#  'course location1 safest place central london\n',
#  'oh location1 without doubt always said would love live\n',
#  'location1 location2 area expensive probably expensive london\n',
#  'nobility live townhouses location1\n',
#  'area south location1 also good\n',
#  'area around location1 location2 station nice leafy green affordable\n',
#  'cheapest area london location1 da18\n',
#  'one place must visit london location1 market\n',
#  'try location1 nearby\n',
#  'try location1 great transport connection lot development last year west london\n',
#  'try searching location1 location2\n',
#  'may want consider location1\n',
#  'find anywhere near london much cheaper location1\n',
#  'area around location1 multi cultural busy area\n',
#  'depends much money spend avoid location1 bad transport alot trouble\n',
#  'come area david agree going live suburbia location1 area good expensive\n',
#  'live location1 north west extended london great busy expensive ether\n',
#  'dont live location1 regret\n',
#  'go location1 centre london\n',
#  'really nice area location2 location1\n',
#  'try somewhere round location1\n',
#  'location1 location2 coming popular place artist musician also lot great curry house asian food shop\n',
#  'try location1 already seen\n',
#  'location2 location1 might good\n',
#  'area like location1 location2 still regarded pleasant safe little le expensive slightly centre town\n',
#  'area location1 location2 near mi either tube line nice area semi rural part\n',
#  'long afford live location1 way nicer\n',
#  'avoid location1 super pricey\n',
#  'avoid location1 nice place go bit rough highest assault rate london\n',
#  'crossrail mainline link location1 central london north kent\n',
#  'part location1 nice area\n',
#  'getting london location1 easy bus go every minute\n',
#  'hmm location1 location2 improving area\n',
#  'however unlikely find anything decent cheap location1\n',
#  'live location1 close center town nice opinion\n',
#  'also like location1 location2 going\n',
#  'understand thumb location1 area lot money thrown right\n',
#  'currently live street depressing hood area location1\n',
#  'love location1 unfortunately due increase rent moving\n',
#  'know location2 location1 one nicest area london\n',
#  'feel safer location1 location2\n',
#  'feel location1 area pretty safe lived e9 location2 loved\n',
#  'got flat broken location1 never location2 area\n',
#  'heard friend location1 place nearby quite dangerous live due high criminal case\n',
#  'lived location1 25 year one safest place live\n',
#  'personally major problem location1\n',
#  'know definitely want live location1 dangerous\n',
#  'know location1 well afraid choose live either\n',
#  'live location1 even walk across road shop without feeling overly warey\n',
#  'live location1 seven year never minute trouble\n',
#  'live location1 quite boring\n',
#  'live location2 love location1 stay away location1 lol\n',
#  'live location2 id rather live location1\n',
#  'must say location1 one favorite place love live\n',
#  'prefer live area english people like live location2 variety different culture like location1\n',
#  'recommend location1 perhaps location2\n',
#  'spent semester abroad location1 right around imperial college would imagine area would greatly expensive great place live\n',
#  'sure hell wanna stuck shithole like bloody location1\n',
#  'think location2 get raw deal close dodgy area like location1 actually alright bit hidden gem fact\n',
#  'think location2 pretty good place live unlikely problem living location1 yeah safe area\n',
#  'think farthest essex close london would location1\n',
#  'used live rented appartment location1 rocking day link centre fast frequent tube underground railway\n',
#  'recommend area like location1 location2 high asian population fairly affordable live\n',
#  'would hardly call location1 location2 rough well honestly rough part every area london\n',
#  'would never want live somewhere like location1 anywhere location2 would never get sleep\n',
#  'would pick location1 furthest center giving much thing\n',
#  'would really recommend location1\n',
#  'would say location1 may exceed budget little worth move\n',
#  'would say massive increase supply around area amount security location1 best bet waste money\n',
#  'would stay away location1 location2 area many part run deprived\n',
#  'would strongly recommend flat location1 area growing quickly many flat newly built meaning design quite modern well\n',
#  'would suggest se london somewhere like location1 location2 year lived london\n',
#  'would suggest looking area around location2 location1\n',
#  'recommend location1 could easily connect onto piccadilly line problem cheaper area london\n',
#  'recommend location2 location1\n',
#  'location1 time never bothered\n',
#  'location1 location2 bleak unfriendly place daylight\n',
#  'lived location1 year love want live anywhere else\n',
#  'never location1 due reputation mostly\n',
#  'spent lot time location1 confirm generally quite deprived area certainly safe dark\n',
#  'alot money ie rich live nice location1 posh\n',
#  'alot money ie rich live nice location1 posh london\n',
#  'range exclusive expensive around location2 market affordable place like location1\n',
#  'keep well clear location1 pit fine\n',
#  'location1 way hot bed crime\n',
#  'location1 good market vibrant afro caribbean community\n',
#  'location1 reputation dangerous\n',
#  'location1 become popular area london quite expensive\n',
#  'location1 connection gatwick luton airport lot cool place might want visit like brighton\n',
#  'location1 good restaurant bar\n',
#  'location1 plenty food place\n',
#  'location1 empire good venue live music good bar\n',
#  'location1 nice area probably bit far away\n',
#  'location1 pretty desirable area see mean\n',
#  'location1 certainly safer even couple year ago\n',
#  'location1 good shopping\n',
#  'location1 crime hotspot probably drunk\n',
#  'location1 quite green area london\n',
#  'location1 nice\n',
#  'location1 commuter hub london\n',
#  'location1 grew okay place live got large portugese community\n',
#  'location1 location2 place low crime\n',
#  'location1 fantastic shopping centre art centre club 25 minute bus ride away\n',
#  'location1 yawn hyped trodden area crime high\n',
#  'location1 good area generally\n',
#  'location1 location2 shite hole\n',
#  'location1 london aint exactly dump cause germanz bombed dey build alot estate init\n',
#  'location1 sort average london suburb racially mixed therefore excellent ethnic restaurant shopping centre usual store\n',
#  'location1 according met one highest crime rate\n',
#  'location1 ai bad either\n',
#  'location1 location2 also good area cheaper flat\n',
#  'location1 location2 expensive scale neighbourhood need worry apart huge cost living course\n',
#  'location1 location2 okay affordable good transport\n',
#  'location1 nice area near cemetery good maybe expensive\n',
#  'location1 large asian community sticking crime rate\n',
#  'location1 lot trendy club pay around 10 15 drink\n',
#  'location1 wicked party really like dont stay\n',
#  'location1 kent lovely ancient market town good fast rail service location2\n',
#  'location1 kent location2 kent might worth look\n',
#  'location1 london good place go hear blue music ronnie scott location2 jazz institution\n',
#  'location1 northern london nice location2 nice south\n',
#  'location1 east end vibrant area young hipster type artist musician people love food specifically indian curry\n',
#  'location1 big flea market street great indian curry house\n',
#  'location1 good place live convenients safe lot pub bar cafe restaurant shop\n',
#  'location1 lovely place live would bit trek london journey time underground northern line 40 minute\n',
#  'location1 pleasent market vibrant cosmopolitan young professional area\n',
#  'location1 pretty rough area lot council estate quite way centre 10 mile poor public transport\n',
#  'location1 really nice area good restaurant etc good transport link jubilee line silverlink train thameslink train\n',
#  'location1 shitt hole location2 ok bit way\n',
#  'location1 average crime\n',
#  'location1 affardoble next central london\n',
#  'location1 different though bit run area dont expect much get however student take safe enough\n',
#  'location1 fine\n',
#  'location1 gorg would love live\n',
#  'location1 gorgeous blend uber rich middle class\n',
#  'location1 great mainly little boutique sell good wont find anywhere else huge market\n',
#  'location1 horrible yes fact last weekend work location1 area within last three week owner sandwich shop directly opposite murdered drug crazed ex employee yesterday man shot dead inside se one nightclub\n',
#  'location1 opinion alot nicer location1\n',
#  'location1 middle class outer suburb problem area aimless bored youth\n',
#  'location1 upmarket residential area west towards surrounding high rd\n',
#  'location1 nice food shopping good luck finding anywhere decent price range\n',
#  'location1 nice cinema shop stuff\n',
#  'location1 ok aint expensive well dunno rich\n',
#  'location1 metropolitan line underground train frequent take 35 minute location1\n',
#  'location1 piccadilly line\n',
#  'location1 one desirable place live whole world beautiful area 10 min location2\n',
#  'location1 15 min location1\n',
#  'location1 10th safest london borough\n',
#  'location1 predominantly safe\n',
#  'location1 quite expensive hint question several part estate agent often call surrounding area location1 people know area\n',
#  'location1 quite pleasant general\n',
#  'location1 really big shopping centre middle huge road junction m1 start\n',
#  'location1 really nice part borough location1\n',
#  'location1 best part whole london\n',
#  'location1 lively term cinema bar restaurant etc\n',
#  'location1 lively term cinema bar restaurant etc probably place list find single woman 40\n',
#  'location1 cheap compared else warned go\n',
#  'location1 leafy wonderful park woodland well within walking distance location1\n',
#  'location1 upmarket many artist live\n',
#  'location1 like location2 desirable area full character atmosphere property area expensive\n',
#  'location1 market plethora stall shop food different culture country\n',
#  'location1 last 10 year restaurant pub bar rival location1 people afford would go area felt unsafe indeed live\n',
#  'location1 part large jewish community live peace\n',
#  'location1 town centre brilliant shopping\n',
#  'location1 used drug prostitution\n',
#  'location1 lovely safe area\n',
#  'location1 excellent night life side got location2 also known rough great market curry\n',
#  'location1 quite trendy good like tennis\n',
#  'location1 would good choice term communication\n',
#  'location1 got good rail link location1\n',
#  'location1 well served public transport five underground station ruislip name\n',
#  'location1 location2 fast becoming hot spot aussie kiwi working london\n',
#  'location1 location2 great area live\n',
#  'location1 se4 beautiful late victorian edwardian suburb south east london\n',
#  'location1 quite hip\n',
#  'location1 enormous westfield shopping centre\n',
#  'location1 gun capital country live known murder mile lower clapton road\n',
#  'location1 big grassy hill ace resturants\n',
#  'location1 cute villagey area load celebs live sweet shop cafe etc\n',
#  'location2 location1 also really rough area\n',
#  'location2 location1 better provided open space le subject traffic airliner noise nuisance\n',
#  'location2 location1 nice\n',
#  'location2 location1 mentioned others good ignore le obvious\n',
#  'location2 location1 area say really outrageously dangerous neighbourhood\n',
#  'location2 afro carib location1 indian\n',
#  'location2 safe enough area part location1 safe\n',
#  'location2 central london extremely expensive location1 often considered coolest area london\n',
#  'location2 fine much happens location1 sw london better every conceivable way\n',
#  'location2 expensive location1 still nice\n',
#  'location2 well served tube location1 tube station\n',
#  'location2 quite nice bad border location1 nice area\n',
#  'location2 location1 would supply great local amenity direct train london\n',
#  'lot bar restaurant location2 could go dog racing also local lot fun say nice area particularly dangerous area live wary around location1 lane estate\n',
#  'mikey location1 disgusting area\n',
#  'location1 fine\n',
#  'hometown location1 sw london literally walk location1\n',
#  'offence anyone life location1 personally would stay away\n',
#  'course cheaper area location1 near london somewhat dangerous\n',
#  'one really nice area location2 location1\n',
#  'personally prefer location1 location2\n',
#  'rent location1 reasonable relatively nice part london\n',
#  'take curry location1\n',
#  'location1 area crowded saturday night plenty bar restaurant lively quite young crowd rented housing expensive\n',
#  'location2 location1 area south london really lively load bar pub restaurant open space well summer\n',
#  'area london location1 heavily populated ethnic minority group particularly bangladeshi muslim\n',
#  'best club london fabric location1 like proper dance music\n',
#  'one got rough part location1 thats basically central london expensive trouble much\n',
#  'town location1 beautiful happily live upcoming youngish area live\n',
#  'victoria albert museum location1 also good\n',
#  'shop location1 know need go central london every time want pint milk\n',
#  'large turkish community live location1 welcome especially\n',
#  'recently article time saying location1 coming area\n',
#  'well location1 home world longest street market\n',
#  'struggle find something affordable desirable area location1\n',
#  'bit like location1 might satisfy mind commuting\n',
#  'nice area location1 location2\n',
#  'strong vietnamese community based location1 sizeable japanese community around location2 area\n',
#  'already looked location1 cannot afford\n',
#  'area like location1 residential leafy\n',
#  'area around location2 nice middle class suburb arty feel lot open space otherwise try location1\n',
#  'area near location1 station lot market store pub\n',
#  'said area around location1 quite rich look online find home available\n',
#  'location1 little seen seems lot commuter flat comment culture nightlife though\n',
#  'avoid location1 old tower block gone still got nice vibe\n',
#  'location1 would close centre\n',
#  'location2 location1 excellent shopping facility\n',
#  'celebrity live location1 quite wealthy area borough location1\n',
#  'cheaper place still central include location2 location1 mentioned answer\n',
#  'live location1 pretty rough especially around location2\n',
#  'even location1 boasting huge rent london worker moving\n',
#  'everybody associate location1 large indian community\n',
#  'everytime stay round friend location1the wlocation1dential area look really depressing dull\n',
#  'example huge jewish turkish community location1 lot chinese people south especially around location2\n',
#  'example could choose live near location1 uncompromisingly nice house would cost upwards million\n',
#  'location1 ten minuet drive location2\n',
#  'go somewhere close location1 possible generally safer\n',
#  'family location1 great place garden 45 minute tube central london\n',
#  'live location1 moment quite far away\n',
#  'live london honest location1 best area\n',
#  'think location2 location1 pretty much go area essex\n',
#  'recommend location1 area low crime far know house pretty reasonable maybe bit expensive worth good access london car think definitely good access public transport\n',
#  'would say part location1 total safe anyone time\n',
#  'would try location1 location2 west london generally decent area cheapest property london found around\n',
#  'say around location1 area market supermarket near like barnard area caledonian road\n',
#  'moving location1 nicer lot expensive\n',
#  'enough money would definitely live location2 location1\n',
#  'head place like location1 probably exceed budget\n',
#  'something bad happens london suburb seven time location1\n',
#  'yorue looking decent meal really head location1\n',
#  'poor location1 great\n',
#  'afford move location1 location2 lovely little area\n',
#  'limitless budget somewhere like location1 great choice upmarket area\n',
#  'move location1 im get cheaper accomodation train 30 minute central london\n',
#  'need le costly place look area around location2 location1\n',
#  'depends location1 going live council astates would live\n',
#  'bad location1\n',
#  'ok live near location1\n',
#  'ive location1 time night without mishap\n',
#  'south location2 called location1 notoriously rough\n',
#  'living near location1 would cool\n',
#  'move somewhere like location2 location1 youre far central\n',
#  'friend location2 location1 experienced much crime seen scary thing\n',
#  'nice place live location1 location2 london\n',
#  'location1 nice\n',
#  'long ago woman shot head phone location1\n',
#  'towards location1 place get affordable area quite green nice despite people say\n',
#  'e8 location1 thing fine\n',
#  'place like location1 location2 good live looking quiet area warned arent central\n',
#  'place location1 south london coming area quite council home nice area close london centre tube stop\n',
#  'tehre reasoanble shop location1 road perhaps quite many nice pub restaurant\n',
#  'location1 area alot cheaper although alot rougher area fairly high crime rate knife gang crime mostly\n',
#  'big advantage location1 transport link finsbury park station got two tube line mainline rail line get anywhere london easily\n',
#  'least environmental impact expand location1 established hub proper transport link\n',
#  'mainline train location1 take 23 minute reach location2 central london\n',
#  'nice part location1 expensive\n',
#  'whole location1 area crowded\n',
#  'northern end location1 also good link town\n',
#  'honest meant location1 end exactly glamorous\n',
#  'try harlequin shopping centre location1\n',
#  'unless area really expensive good area location1 general quite rough\n',
#  'absolutely check location1\n',
#  'actually get train directly london airport location1\n',
#  'buy property round location1 one cheapest area inner london\n',
#  'travel central london dlr easily al location1 night bus night take back\n',
#  'could go location1 comparitively cheap quite safe\n',
#  'could try living town like location2 location1\n',
#  'nothing fear location1 safe\n',
#  'maybe try location1 convenience travel 2012 olympics\n',
#  'problem location1 nice place\n',
#  'wo meet many scary poor people location1 posh area unlike\n',
#  'similarly neither jubilee line mean odd time end going half way round world go two stop making location1 seem bit cut time\n',
#  'location1 great lazy sunday morning walk\n',
#  'however best thai restaurant london location2 live location1 one burbs\n',
#  'live location1 think great\n',
#  'location1 lot btw\n',
#  'offence anyone living used visit someone location1 soooooooooooo depressing\n',
#  'avoid location1\n',
#  'highly recommended location1\n',
#  'need worry problem area location1 safe pleasant suburban town\n',
#  'mention area location1 side location1 generally bit quieter leafier\n',
#  'afford close london consider location1 probably nicest area within spitting distance london\n',
#  'location1 location2 bloody gorgeous expensive\n',
#  'location1 central easy get anything residential\n',
#  'location1 full hotel much turistic thing course think count\n',
#  'location1 also lot flat share good transport link\n',
#  'location1 location2 bit side hip happening bit drab\n',
#  'high street get busy weekend summer location1 listed tourist guide must see alternative place london\n',
#  'location1 nice place live\n',
#  'tried somewhere outskirt like location1 location2 ect\n',
#  'location2 location1 area still cheapest rent buy london\n',
#  'bit towards suburb location1 location2 pleasant area\n',
#  'cheaper option yet location1 right river location1\n',
#  'cool place eat drink location2 location1\n',
#  'great place location1 middx london postal name location2 surrey\n',
#  'new sainsbury local opened next location1\n',
#  'visit one westfield shopping centre location1\n',
#  'let know location1 location2 beautiful area load pretty garden square park still really urban fancy get noisy thats pretty much\n',
#  'actually location1 quite expensive cricket ground close proximity vaxhaull\n',
#  'actually location1 tube network\n',
#  'actually private rent location1 seem affordable london standard\n',
#  'add location1 location2 good area\n',
#  'ah dream location1 lot around quiet weekend peaceful\n',
#  'airport wise there much location2 location1 good tranport link central london\n',
#  'around location1 many rich people classy home\n',
#  'crime figure average location1 dangerous either two place\n',
#  'free think two would probably also enjoy huge botanic garden location1\n',
#  'think location1 best place london live\n',
#  'think either location2 location1 worst area ever east end london\n',
#  'place except location1 mainline station southeastern get central london location2 25 minute le\n',
#  'alot location1 redeveloped getting better better\n',
#  'alright location1 location2 would best\n',
#  'also location2 slightly mixed demographic compared affluent location1 certainly coming good amenity jubilee line efficient sainsburys\n',
#  'also nearby location1 also great microbrewery brew sell beer site\n',
#  'also location1 location2 quite safe nowadays\n',
#  'also location1 train station london underground national rail take location2\n',
#  'also location1 like much bit expensive\n',
#  'also location2 although bit train journey work lifestyle good location1 bit reputation\n',
#  'also avoid location1 location2\n',
#  'also consider location1 well right next canada water\n',
#  'also could look around location1 area think thats grad student go\n',
#  'also take look area location1 location2\n',
#  'also try location1 one favourite place capital\n',
#  'also try location1 one favourite place capital populated lot wealthy people long plenty cash pay rent great time\n',
#  'also worth visit location1 famous horsestable market like aladdin cave curio\n',
#  'also location1 national rail overground train\n',
#  'also general rule location1 cheapest area followed closely location2\n',
#  'also might want check location1 posh area north centre nice upmarket pub cafe deli\n',
#  'alternatively trent park location1 small animal section\n',
#  'alternatively move somewhere like location2 ro location1 isnt london still within 30 minute\n',
#  'alternatively try location1 location2 load bar restaurant\n',
#  'alternatively location1 likely closest centre get still able pay rent bill without eating bread butter month\n',
#  'although location1 bad reputation past lived year found area live friendly quiet\n',
#  'although location1 picturesque park quite high crime rate close centre london rarther expensive\n',
#  'although area lacklustre reputation housing stock around location1 cheap\n',
#  'location1 certainly overpriced although isnt london\n',
#  'another area location1 would cheapest list high crime rate think location2 n7 getting expensive solid reason\n',
#  'another area might look location1 quality journey gatwick longer yeah east location2 fairly accessible london\n',
#  'another nice area location1\n',
#  'another nice little town close location2 location1\n',
#  'another option location2 location1 surrey\n',
#  'another place would suggest location1 around corner st paul\n',
#  'another place great go location1\n',
#  'another regularly excellent venue location1 market free live jazz classical gig four time week\n',
#  'location1 area good\n',
#  'location1 rough dangerous\n',
#  'anyhow location1 nice live lot going night taking night bus home suck well cause tube stop 12ish\n',
#  'anyway london huge location1 probably best bet\n',
#  'anywhere location1 location2\n',
#  'anywhere around location1 coming new olympic village built accompanying westfiled shopping centre\n',
#  'apart crime go location1 whole amazing cultural vibe\n',
#  'area location1 nice would avoid location2\n',
#  'area quite far north location1 really nice\n',
#  'area location1 location2 lovely residential quiet close center\n',
#  'area location1 location2 good low crime level\n',
#  'area location2 location1 pleasant expensive\n',
#  'area dont feel quite safe place like location1\n',
#  'around location1 probably best choice\n',
#  'around location1 n4 good public transport choose location carefully\n',
#  'location1 black community location2 chinese etc\n',
#  'location1 isnt tube housing bit cheaper think fairly nice\n',
#  'general rule avoid certain area south london location1 location2 complex bad reputation drug gun crime\n',
#  'far know looking low crime rate location1 really option\n',
#  'far living nearby location2 location1 much better\n',
#  'far safety go would say location1 would better choice live location1\n',
#  'location1 well safest place\n',
#  'location1 equally affluent come exclusive real state world\n',
#  'area live yeah location1 sw15 great youre millionaire\n',
#  'location1 great indie pub gig location2\n',
#  'others said avoid location1 like plague got soul\n',
#  'someone live location1 compared place london location1 rough area\n',
#  'soon go outside zone location1 price high\n',
#  'well steeped rich history location1 living thriving vibrant community\n',
#  'earn decide positively live start earning location1 rough dangerous\n',
#  'aside warn housing price probably ridiculous location1\n',
#  'location1 see cutty sark ship museum see 00 latitude greenwich mean time start\n',
#  'least location1 tube\n',
#  'least location1 etc alot violence\n',
#  'night prostitute take location1 road lining main street pimp hooker way location2\n',
#  'heart london location1 area accessible proximity buckingham palace\n',
#  'avoid location1\n',
#  'avoid location1 near location2 nice live\n',
#  'avoid location1 dirty dangerous grim\n',
#  'avoid location1 location2 working\n',
#  'avoid location1 awash criminal\n',
#  'avoid location1 one rough deprived area london\n',
#  'avoid location1 cost\n',
#  'avoid location1 dirtier dangerous aware lot council housing area\n',
#  'avoid location1 unless totally hardcore\n',
#  'avoid location1 come like bloody black death\n',
#  'avoid location2 location1 alot crime area\n',
#  'avoid location1 lot knife crime location2 mainly asian dominated area sot bengalies\n',
#  'avoid area around location1 like plague\n',
#  'avoid called murder mile round location1 location2 north london\n',
#  'based research far location2 location1 sound like nice place live value money reasonably safe bar cafe\n',
#  'basically yes place leafy fairly quiet ever quiet outside london location1 okay\n',
#  'location1 area built fast find lack character building house built fast majority made specification\n',
#  'better area include location1 location2 instance\n',
#  'blue lover miss legendary billy chong blue band jam globe pub location1\n',
#  'borderline location1 affluent trendy love live\n',
#  'great shopping centre location1 giant glade location2 whitgift centrale centre\n',
#  'bottom line either looking house live investment recommend location1 big time\n',
#  'reckon location1 way go\n',
#  'think location1 good bet\n',
#  'choose location1\n',
#  'location1 safe get expensive\n',
#  'location1 one big dump know got information true\n',
#  'location1 would definitely expensive find place live difficult answer one name suggests mediterranean extraction number answerer may consider italian white\n',
#  'across location1 nice suburb many mention\n',
#  'aside image find location1 balance prosperous youthful town\n',
#  'avoid immediate area around lhr inc location1 location2\n',
#  'location1 worth avoiding living condition quite bad deprived area\n',
#  'said pool knew trolling yes agree troll luddite area london safer others location1 according met one highest crime rate\n',
#  'yes london location1 great area\n',
#  'get best world leafy location1 10 min walk one direction non stop location1 ever find place budget\n',
#  'london standard location1 cheap area mostly pretty run area\n',
#  'going like location1 price drop significantly\n',
#  'callooh callay bar loungelover barrio east nightjar favourite place drink location1\n',
#  'central london generally getting much much much expensive day location1 comparison zone location still seems good value\n',
#  'certain part location1 feel bit dicey particularly night area part like\n',
#  'certainly location1 location2 nice part expensive live\n',
#  'cheaper option nearby location2 location1 suddenly price go crime go always compromise\n',
#  'cheapest area around location1 would want live\n',
#  'cheapest location location1 location2 looking rent buy\n',
#  'check location1 zone\n',
#  'check following idea place like location2 location1 cheaper\n',
#  'check park like location1 nice\n',
#  'come live location1 location2\n',
#  'come think location1 great location\n',
#  'commuting stick location1 either drive catch district line location1\n',
#  'could try location1 well\n',
#  'could try location1 well hometown location2\n',
#  'definately location2 poosssibly location1\n',
#  'definitely recommend location1\n',
#  'defo location1\n',
#  'dependent two option location1 location2 lovely green area great view london\n',
#  'disavantages area gun crime high robbery theft vehivles area like location1\n',
#  'walking tour ghost jack ripper location1 area get real story london famous people live\n',
#  'live location1 location2 two area higher rate crime knife gun murder\n',
#  'afraid london different london south london location1 notorious\n',
#  'expect much night life location1 handy full beauty life\n',
#  'stray far towards location1 would even happen walking still quite bit away actually think location1 bit hidden gem\n',
#  'really think anybody right mind would move location1\n',
#  'even think driving working location1\n',
#  'even think living location1 lot gang hoodies stabbings\n',
#  'even think living location1\n',
#  'hang location1 nice place\n',
#  'live location2 naaa there nothing wrong location1\n',
#  'dont go location2 stay seriously find location1 lot richer great transport link\n',
#  'driving location1 london awful congestion charge parking extremely expensive\n',
#  'easy try location1 used predominantly jewish area home many middle eastern people want arabic muslim jew\n',
#  'eg wouldnt move location1\n',
#  'enjoy location1 free nice park lot goin\n',
#  'enjoy time location1 really fantastic historical part world\n',
#  'even location1 nice bit\n',
#  'even avoid location1 location2\n',
#  'even tho bare mate location1 used hang around alot still queit bad part town\n',
#  'everything slightly expensive location1 location2\n',
#  'explore location1 boutique well\n',
#  'fire location1 shirtless man man clubbing dancing large scale\n',
#  'first capital connect train go location1 station would faster riding underground\n',
#  'flat location1 location2 cost 30 000 000 afford nice nightlife\n',
#  'baker st try location1 borough north baker st cheaper easier get\n',
#  'short commute could try somewhere around location1 nice popular commuter\n',
#  'affordable try location2 location1\n',
#  'let location1 might everyone cup tea due many factor crime rate kind neighbour get ect\n',
#  'example used live location1 se1 fashionable london pad trendy type also rough dodgy housing estate\n',
#  'example lot people live location1 location2 great bar restaurant quite trendy\n',
#  'example many immigrant living around location1 london borough location2\n',
#  'instance price around location1 already increased significantly due olympics redevelopment done\n',
#  'museum location1\n',
#  'safe head location1 location2 fistful cash\n',
#  'part location1 nice area\n',
#  'value money good transport link great amenity would recommend location1 sw location2 nw\n',
#  'foreigner find multiple reason choose location1 settle\n',
#  'forget location1 whole location2\n',
#  'forget location1 residential place highly expensive central even nice area\n',
#  'forget location1 unless lot money speak hewbrew\n',
#  'forget location1 unless want live area rife gang drug culture\n',
#  'frankly fan location1 though location2 always good option excellent local school wonderful shopping\n',
#  'location1 london 10 minute train\n',
#  'location1 centre london 45 minute train\n',
#  'location2 location1 central line whisk straight chancery lane around 30 40 minute\n',
#  'tudor period onwards location1 became popular recreation leisure destination wealthy londoner\n',
#  'list maybe location1 would good\n',
#  'map see location1 dangerous borough even though contains major tourist attraction buckingham palace house parliament famous shopping road oxford regent street\n',
#  'location1 location2 quite lively\n',
#  'centre location1 pretty decent place would advise staying clear location2\n',
#  'generally location1 best bet really depends budget\n',
#  'generally would recommend location1 unless really big budget\n',
#  'generally location1 cheapest rent buy property\n',
#  'giving location1 wide berth might best course action\n',
#  'go location1 location2\n',
#  'go location1 unique night load club bar go partying\n',
#  'good luck worked extensively around london would agree location1 would first choice live\n',
#  'good tesco supermarket behind location1 got bit noisy ash\n',
#  'good luck like location1 good location surrounded good shop\n',
#  'good luck would suggest looking location1 location2\n',
#  'good luck location1 quite nice area work\n',
#  'good luck god bless location1 restaurant cafe urban town feel three close\n',
#  'good shop near location1 easy access location2\n',
#  'good transport bus location2 location1 bad bit rough rundown part\n',
#  'goth punk rock pub countless music venue load food 188 location1\n',
#  'great location location1\n',
#  'great place location2 location1\n',
#  'harrod location1 store boast get anything want\n',
#  'look website might help location1 north west good transport typical mix people london live left london map reading\n',
#  'born location1 appreciate reluctance\n',
#  'lived location1 think need stay away dodgier part crime prob rife\n',
#  'said though location1 lovely lived location2 also really nice\n',
#  'good guide walk information free article history read location1 still charming katherine parr lived husband thomas seymour played young princess elizabeth\n',
#  'one side dual carriageway side looking much different normal location1 nightmare time\n',
#  'location1 sizeable shopping area vue cinema regular department chain store stack bar restaurant also lot green space around enjoying kind weather today\n',
#  'hi live south london location1 nearest tube station\n',
#  'hi based apartment location1 month trouble convenient location\n',
#  'highstreets well location1 defiantly best high street shop rearurants much\n',
#  'historic afraid area close proximity location1 come cheap\n',
#  'hope helped location1 nice area sort thing\n',
#  'hope help lived edge location1 think great area live\n',
#  'hope help without doubt location1r location2 se16 south river best place live\n',
#  'however location1 abit rough\n',
#  'however location1 really nice borough\n',
#  'however location1 best place live\n',
#  'however probably quite expensive next location1\n',
#  'however many people exagerate like location1 used live went everynight dark coming back work byh absoloutly fine\n',
#  'however boyfriend life location1 seems like lovely place live\n',
#  'however perhaps would feel location1 location2 appropriate\n',
#  'however location1 far away central london compared location2 lsb\n',
#  'however location1 generally cheaper location1 le tube station\n',
#  'however location1 safe peaceful nearby osterley park attractive\n',
#  'however part location1 quite pricey warned\n',
#  'however life location1 place feel safe using station\n',
#  'however since olympics going based location1 house price going\n',
#  'say enough money location1 actually really lovely\n',
#  'suggest west london though location1 location2 pretty economical\n',
#  'particularly familiar would cost bear mind would cheap location1 mixed area central london\n',
#  'sure pub whether people living mainly single though location1 fine\n',
#  'heard location1 location2 bad either\n',
#  'heard location1 bit chavvy sorry true\n',
#  'heard location1 good place live term rent low crime rate\n',
#  'heard location1 safe police officer idea expensive\n',
#  'love location1\n',
#  'live location1 close center town nice opinion\n',
#  'agree location1 little better easy commute location1\n',
#  'agree location1 good\n',
#  'agree poster location1 lovely part town gorgeous restaurant\n',
#  'agree answer avoiding location1 area\n',
#  'also like location1\n',
#  'also think location2 location1 nice safe latter bit le expensive\n',
#  'also went see location1 bit run look nice either\n',
#  'also went see flat cheaper area location1 location2 biggest dump ever seen ghetto feel\n',
#  'always sing praise east location1 great\n',
#  'currently living location1 need buy bigger house family expanding afford buy sn\n',
#  'fan location1\n',
#  'presuming location1 mentioned near euston overland rail station central london\n',
#  'sure enjoy living location1 lived adult life think great place borough location1 overall nice friendly area\n',
#  'told location1 lowest council tax perhaps mean service council provide good borough\n',
#  'afford live somewhere like location1 wanna live dump like location2\n',
#  'live location1 year found comfortable area\n',
#  'love location1 would stayed able afford rent price silly\n',
#  'know location2 location1 affordable property renting buying\n',
#  'know clanricarde garden location1 pretty safe easy get place via tube\n',
#  'know budget location1 favourite place could afford would live\n',
#  'know location1 know zone cost fare\n',
#  'know much location1 apart lot tube station think price reflect\n',
#  'know crime figure looking overall crime location1\n',
#  'like location1 always ramo\n',
#  'live location1 afford\n',
#  'really know area read online location1 location2 bad violent area\n',
#  'enjoyed living location1 proper mutli cultural london suburb\n',
#  'felt safest location1 location2\n',
#  'day trip location1 last year partner see black face day\n',
#  'friend lived location1 full drug dealer stay away central location1\n',
#  'look internet seems area unsafe like location1\n',
#  'lived 10 year location1 never witnessed trouble\n',
#  'lived location1 25 year one safest place live\n',
#  'lived location1 past six year love\n',
#  'lived location1 past quite nice train link\n',
#  'lived location1 area year trouble\n',
#  'lot mate live location1 cool bar lot cultural food especially indian\n',
#  'never back location1 absolutely horrible area returning hurry\n',
#  'idea website help find answer location1 good access london via train bus warned safest place dont go round flashing ya cash mobile phone\n',
#  'moved location1 havent problem either\n',
#  'told couple people borough location1 location2 best combination cheap safe\n',
#  'heard location1 amazing shop especially rockabilly punk indie pin type thing\n',
#  'heard location1 residental fun place leave fun location2\n',
#  'heard location1 ok problem find student hostel around\n',
#  'honestly fear walking around location1 time\n',
#  'hope could tell area outskirt london location1 example quieter le expensive\n',
#  'know people like location1 used like going university\n',
#  'know someone else location1 one expensive area london robbed knife point walking block\n',
#  'know part location1 rumoured dodgy discovered find nice street fine london safe large city go location2 exactly safest part worst either\n',
#  'like location2 location1\n',
#  'like location1 location2\n',
#  'like location1 clean overly populated like area live\n',
#  'like location1\n',
#  'like leafy location1\n',
#  'like many place london would choose somewhere like location1 location2\n',
#  'like location1 view page maybe help good lucky\n',
#  'liv tower hamlet location1 place lot violence happens wiv gang\n',
#  'live close location1 location2 feel perfectly safe\n',
#  'live sunny location1 really need car getting\n',
#  'live location1 believe got everything looking\n',
#  'live location1 like much\n',
#  'live location1 feel quite safe\n',
#  'live location1 great\n',
#  'live location1 moment lovely lot foreign people choose move\n',
#  'live location1 preparing move reluctantly expensive\n',
#  'live location1 location2 pretty safe\n',
#  'live location1 north quite brilliant want\n',
#  'live location1 crazy crime gun knife hoodies chavs\n',
#  'live location1 leafy street around nice 10 minute walk away huge estate full drug dealer\n',
#  'live location1 love much central hell lot busier tourist\n',
#  'live location1 one cheapest part london cheapest\n',
#  'live location1 pit\n',
#  'live location1 herts one bed flat around 700 800 month nice area\n',
#  'live location1 advice consider\n',
#  'live location1 best place london far concerned\n',
#  'live location1 great\n',
#  'live location1 considered bad people live go location2 night\n',
#  'live location1 considered one better area mugged twice\n',
#  'live london quite happy walk around location1 would scared walk around estate location2\n',
#  'live london hope realise location1 one run area london home notorious estate uk\n',
#  'live edge location1 great access green space outdoor swimming local independent shop cafe plus generally nice safe neighbourhood\n',
#  'live slightly location1 sw london also pretty lively reasonable number shop quite nice bar restaurant bit cheaper\n',
#  'live slightly location1 sw london also pretty lively reasonable number shop quite nice bar restaurant bit cheaper think area\n',
#  'lived worked poor area london called location1 fill social problem\n',
#  'lived location1 life bit 22nd birthday incident\n',
#  'lived location1 12 year never felt unsafe\n',
#  'lived location1 couple year able walk central london\n',
#  'lived location1 four year worst thing public transport suck\n',
#  'lived location1 yr never problem\n',
#  'lived location1 six year without problem crime\n',
#  'lived location1 year year bother\n',
#  'lived london 57 year time attacked posh old location1\n',
#  'lived border location1 location2 year never witnessed became victim sort crime\n',
#  'lived border location2 location1 almost year never problem\n',
#  'looked option opted location1 kent end mainly green rural also one last stop fast coast train get london\n',
#  'love location1\n',
#  'love location1 great place spend day wandering around shop stall end end buying something\n',
#  'love going location1\n',
#  'love around location1\n',
#  'love living near location2 location1\n',
#  'love visiting location1 imagine would great place live\n',
#  'loved location1 lived good shop restaurant pub location2 location1 excellent public transport\n',
#  'loved village thought location1 beautiful especially lake took 30 minute get location2 rd\n',
#  'met quite often spanish speaker location1 area\n',
#  'must say though want really nice south thames check location2 location1\n',
#  'live location1 much prefer\n',
#  'live location1 much prefer moment live location1\n',
#  'live location1 lovely set neighbour sort ethnic background\n',
#  'lived location1 month really liked area\n',
#  'particularly like location1\n',
#  'personally would never live location2 location1 dirty\n',
#  'prefer gravadlax assuming want keep kosher location1 place go top restaurant\n',
#  'rather like location1\n',
#  'really think location1 good comparison though location1 great place live\n',
#  'really enjoyed living location1 location2\n',
#  'really like location1 kind area expensive\n',
#  'really know stay away location1 location2\n',
#  'reccomend look somewhere location2 location1\n',
#  'recently moved location1 west london rent high\n',
#  'rent decent large bed flat location1 decent price\n',
#  'say location1 best place location2 nice quite area\n',
#  'also mentioned december south east train running fast service location1 st pancras international\n',
#  'spent 18 month living location1 wasnt safest area\n',
#  'spent four year studying living working location1 loved every minute\n',
#  'stayed one location1 tube line location2\n',
#  'think location1 even location2 much better\n',
#  'think location1 bad area probably le rough location1\n',
#  'think location1 location2 great area\n',
#  'think location2 better prejudiced location1 one expensive area london\n',
#  'think location2 ok place location1 nicest area\n',
#  'think pretty much place location1 safe although location2 sometimes bit dodgy\n',
#  'think great care taken location1 preserve park green area\n',
#  'think location2 location1 area would absolutely perfect\n',
#  'think best area london live cheap safe location1\n',
#  'think influenced big swathe northwest location1 covered sm1 endless utilitarian residential street precious green space natural feature enhance landscape\n',
#  'think find location1 lot crime location2\n',
#  'used live location1 liked\n',
#  'used live location1 location2 problem\n',
#  'used live location1 also bad reputation never trouble despite coming home alone late night 2am\n',
#  'used live road location1 afford buy live north london\n',
#  'used live location1 road honest nicest fun place ever\n',
#  'usually stay location1 visiting london extremely expensive\n',
#  'always location1 area going pub shopping walking around fun\n',
#  'location1 weekend part around gorgeous\n',
#  'location1 location2 area summer thought looked like perfect place live\n',
#  'keen location1\n',
#  'told location1 good\n',
#  'work location1 area price range considered clapton\n',
#  'would definitely recommend location1\n',
#  'would feel le safe walking around location1 night elsewhere lb location2 relatively speaking\n',
#  'would go location1 though afford\n',
#  'would said location2 location1 obviously nice hardly affordable\n',
#  'would like live location1 location2\n',
#  'would look location1\n',
#  'would say location1 dangerous exactly definitely higher crime rate many area\n',
#  'would want live either location1 nice house build along canal olympics force council improve matter\n',
#  'would feel safe walking night location1\n',
#  'would pick location1\n',
#  'would prob say location1 nicer location2 boxy\n',
#  'would put good word location1 though\n',
#  'would recommend location2 location1\n',
#  'would recommend suburb called location1 thames link line large underground station making transport convenient\n',
#  'would recommend either location1 location2 alternative\n',
#  'would say location1 affordable area grab bed flat 250k\n',
#  'would say location1 brondesbury park definitely ideal place\n',
#  'would say location1 expensive\n',
#  'would say location1 one nicer area list housing really expensive\n',
#  'would say somewhere like location1 location2\n',
#  'would suggest location1\n',
#  'would suggest location1 west london\n',
#  'would suggest location2 location1\n',
#  'would suggest living location1 pleasant area\n',
#  'would suggest consider smaller city like location1 looked picture think gorgeous\n',
#  'would suggest best place live location1 south london\n',
#  'would try avoid living location2 location1 close lot council estate generally\n',
#  'live location1\n',
#  'live location1 could avoid\n',
#  'want live council estate location1\n',
#  'west part read location2 location1 becoming popular trendy among youth\n',
#  'go location1\n',
#  'avoid location1 location2 nice\n',
#  'avoid nearby location1 though\n',
#  'certainly prefer location1 location1\n',
#  'go central location2 location1\n',
#  'prefer stay close possible major location1 hub\n',
#  'rather live location1\n',
#  'rather live location1\n',
#  'recommend location1 able get least reasonably sized studio one bedroom flat price around\n',
#  'recommend location1 particular near location1 feel safe\n',
#  'recommend location1 location2\n',
#  'say location1 location2 would best area within easy reach\n',
#  'stay away location1 cost transport rubbish\n',
#  'suggest looking location2 location1 good website gumtree\n',
#  'go location1 particularly location2\n',
#  'fan location1 though\n',
#  'living location1 moment extremely unhappy area bit scary night need move asap\n',
#  'living location1 right brother sister pretty nice\n',
#  'living location1 yeah safe area calm enough everywhere might happen run bad people\n',
#  'mounique 14 live location1 london deprived area high crime massive gang around cause trouble\n',
#  'ready get property ladder location1 budget\n',
#  'sorry dear want affordable area mentioned looking area like location1\n',
#  'used living bad area move location1 amazing\n',
#  'always found location1 feel quite safe nearer location2 feel bit le secure\n',
#  'always liked location1 location2 meself hon\n',
#  'always loved area around location1\n',
#  'recommendation stay along bayswater road around location1 station nicer safer\n',
#  'heard ex work mate council area location1 nice personal experience though\n',
#  'heard location2 location1 dangerous\n',
#  'learned location1 home luxiury wealth\n',
#  'lived location1 life many problem location1 changed much\n',
#  'spent lot time location1 confirm generally quite deprived area certainly safe dark\n',
#  'money option could house particular place would say location1\n',
#  'id love live location1 area look nice clean transport great\n',
#  'could afford buy would location1 one expensive area london lot single people\n',
#  'million spare love buy house location1\n',
#  'wanted near centre would go location1 east\n',
#  'personally buying property london would probably go location1 great area always demand\n',
#  'anyone offered place location1 jump\n',
#  'choose two would definitely go location1 though\n',
#  'lifestyle want afford location1 popular young trendy work crowd mainly medium type lot nice bar restaurant organic bakery like\n',
#  'expensive location1 would good bet well\n',
#  'central location1 rich\n',
#  'take dlr location1 enjoy big shopping mall\n',
#  'young male drug dealer take part occasional heist yes location1 could dangerous\n',
#  'average person wont able afford live right near location2 location1\n',
#  'end adjoining location2 location1 right\n',
#  'looking somewhere bit quieter try location1 somewhere like\n',
#  'bothered train tube station could try location1\n',
#  'planning going much evening location1 would ok\n',
#  'main location1 may noisy\n',
#  'rich might live location1\n',
#  'thinking north perhaps look location1\n',
#  'young want nightlife lively area location1 good\n',
#  'afford move somewhere better location1 location2\n',
#  'afford live location1 go\n',
#  'come london majority tourist attraction based location1\n',
#  'consider living bengal asian location1 good\n',
#  'lot budget could flat share location1 quite expensive\n',
#  'end sure check location1 market like vintage small designer handmade stuff especially clothes\n',
#  'go little west location1 location2 still near central area presumably pay litlle le chk berlin\n',
#  'go tube west location1 nice\n',
#  'little money look location1 location2\n',
#  'load money location1 beautiful expensive depends budget location1 one poshest\n',
#  'like london living want near centre london location1 good choice\n',
#  'look map location1 generally cheaper live location1\n',
#  'must live london would suggest location1 far life\n',
#  'need commute london daily basis location1 end district line decent area\n',
#  'really want action could even live location1 kind money\n',
#  'scoot across little way location1 nice location2 pretty rough\n',
#  'want bit better quality life consider location1 location2 nicest opinion\n',
#  'want nice peaceful area live would suggest location1\n',
#  'want place near centre fairly cheap try location1\n',
#  'want proper genuine street market visit location1 market near ladbroke grove saturday\n',
#  'want cheaper head towards location2 location1 cheaper would convenient travel wise london\n',
#  'want lot club bar one place would suggest location1\n',
#  'want posh near location2 go location1\n',
#  'want slightly nicer look home location1\n',
#  'want something cheaper look location2 location1\n',
#  'want somewhere funkier trendier location1\n',
#  'want take risk walk around location1 istan\n',
#  'go somewhere like location1 would long commute london\n',
#  'interested music journalism nightlife somewhere like location1 location2 place\n',
#  'looking buying flat location1 bring lot money\n',
#  'budget stretch could try bit road location1\n',
#  'poor cant live location1 without paying hell lot one tiny bedroom\n',
#  'location1 got big three vanda natural history museum science museum\n',
#  'location2 location1 nice street\n',
#  'west london area location2 location1 nicelots green space nice housing good transportation link expensive\n',
#  'contrast location1 lovely leafy extremely highly sought house price roof\n',
#  'fact think better fo lo live location1\n',
#  'fact never even seen fight street location1 go time week\n',
#  'fact location1 location2 two cheapest london borough\n',
#  'fact people know mugged two people living location1 one expensive area london location2 another ridiculously expensive area\n',
#  'general location1 good choice research might able find good house share bed flat decent rental price\n',
#  'living working location1 say im pretty happy live however live right river\n',
#  'first year lived location2 location1 definitely safe central area relatively affordable\n',
#  'inner suburb like location1 location2 also worth considering especially plan go night want taxi ride home wo cost fortune\n',
#  'location1 poor multicultural area\n',
#  'nice locale pretty much match description looking probably find place round suitably expensive location1 okay\n',
#  'actually quite good location1 desirable area amazing afford live student\n',
#  'similar lb location2 opposite side honest location1 safest place world get nicer south\n',
#  'true upmarket area london location1 right mix rough smooth\n',
#  'also depends far need travel work much issue london location1 undoubtedly nicest area im prob bit biased\n',
#  'boost exciting thing like royal observatory rolling slope tennis court deer enclosure etc like park fond recreation location1 definitely right place\n',
#  'depends mean bad even location2 location1 area wary night safety reason\n',
#  'matter side location1 safe go school ive never problem location1\n',
#  'large jewish community going towards location1 plenty matzo salt beef bagel\n',
#  'mainly muslim immigrant location1 live\n',
#  'ok honest location1 got lot better used really cleaned act\n',
#  'big place location1 cost location1\n',
#  'work location1 great bar shop cafe restaurant etc really easy commute place central london\n',
#  'also got excellent transport infrastructure connecting location1 central london\n',
#  'close everything different tube line converge location1 station\n',
#  'shopping area location1 full interesting shop restaurant\n',
#  'going walk around lake location2 location1 made think perfect place live\n',
#  'living location1 mean automatically become victim crime\n',
#  'looking briefly show closer centre dangerous area location1 crime\n',
#  'stay away location1 location2 lane\n',
#  'stay away location1 location2\n',
#  'stay away location2 location1 gang crime capital\n',
#  'know people location1 affordable decent close decent place\n',
#  'lb location1 closer centre\n',
#  'location1 lot market stall selling alternative punk goth stuff\n',
#  'location1 saying expensive\n',
#  'location1 relatively safe pleasant close country large forest called location2\n',
#  'location1 location2 lovely\n',
#  'location1 dark night safe\n',
#  'location1 comparison surrey postcode option affordable\n',
#  'location1 lot nice shop restaurant\n',
#  'location1 soul proper shop\n',
#  'location1 also area might lucky enough find two two half bedroom flat price range\n',
#  'location1 getting better\n',
#  'location1 nothing special\n',
#  'location1 offer best term value money location2 expensive\n',
#  'location1 tube station bad friend stabbed\n',
#  'location1 br3 nice suburb mostly safe clean nice park good train link might well find something price range\n',
#  'location1 sw18 another ok area\n',
#  'location1 sw4 good range restaurant tube station good rail bus link lot pub\n',
#  'location1 mainly e14 smart comfortable long way everywhere totally dead night\n',
#  'location1 n1 n2 nice area easy link get central london expensive either\n',
#  'location1 grew okay place live got large portugese community\n',
#  'location1 love\n',
#  'location1 location south west expensive area location2 location central beautiful expensive suburb\n',
#  'location1 location west fair way central london nice suburb bar pub\n',
#  'location1 location north west quiet cheap location2 broadway location west fair way central london nice suburb bar pub\n',
#  'location1 location south west fairly central suburb o2 shopping centre\n',
#  'location1 sloan square nice area saatchi gallery great museum definitely worth visit\n',
#  'location1 lively area going shopping 10 minute bus ride away\n',
#  'location1 generally cheapest part london live landing place immigatrion uk since record began\n',
#  'location1 especially near high st posh place live\n',
#  'location1 example trendy coming area may like\n',
#  'location1 bad reputation developing area looking great\n',
#  'location1 portobello mkt antique flea mkt bit new designer thrown week day fruit veg mkt bit hugh grant walk along film notting hill\n',
#  'location1 notorious area\n',
#  'location1 another coming area pretty central crime bad\n',
#  'location1 bit alternative big rock jazz influence amy winehouse lived might find okay flat central\n',
#  'location1 good shop nice restaurant bar little central london easy get place central line bus\n',
#  'location1 nice family neighbourhood\n',
#  'location1 coming popular young professional\n',
#  'location1 bit good neighbourhood good school\n',
#  'location1 boring area\n',
#  'location1 great ride easy get train\n',
#  'location1 posh expensive\n',
#  'location1 wildly overpriced cool\n',
#  'location1 location2 area lovely brother life wife two young child happy\n',
#  'location1 location2 still right central london youll close everything\n',
#  'location1 council usually good helpful\n',
#  'location1 london farm award winning cafe well pig goat sheep\n',
#  'location1 london farm donkey ride pony care class milking demonstration available request well range talk farm lot hand work animal\n',
#  'location1 market amazing alternative street fashion novelty multi cultural street market colourful full street art canal narrow boat vintage punk one boutique antique music\n',
#  'location1 market pretty much tourist\n',
#  'location1 road plenty restaurant coffee shop many israeli\n',
#  'location1 se10 full pub club bit local history\n',
#  'location1 station connected london bridge railway station victoria station\n',
#  'location1 village easily walkable extremely pleasant probably bit pricey accommodation literally like country village doorstep inner london\n',
#  'location1 village gorgeous expensive part almost feel rural\n',
#  'location1 village near common far nicer afford\n',
#  'location1 decent neighbourhood plenty great bar famous market portobello enough restaurant shop transport option keep happy\n',
#  'location1 generally safe area need scared travelling alone\n',
#  'location1 good transport depending go could spur fan area\n',
#  'location1 cheap though\n',
#  'location1 also lot cheap nice flat hope dis help\n',
#  'location1 also cool unique shop easily spend day eating shopping clubbing\n',
#  'location1 also good transport link centre town district line good overland rail service\n',
#  'location1 also good restaurant\n',
#  'location1 location2 live really posh area even tv show\n',
#  ...]

# %%
# Use tf-idf features
tfidf_vectorizer = TfidfVectorizer()
tfidf = tfidf_vectorizer.fit_transform(corpus_text)

# Use tf features
#tf_vectorizer = CountVectorizer(stop_words=stops)
#tf = tf_vectorizer.fit_transform(review_text)

# %%
tfidf_np=tfidf.toarray()
tfidf_np.shape
# Out:
# (3724, 3888)

# %%
from sklearn.decomposition import LatentDirichletAllocation

LDA = LatentDirichletAllocation(n_components=20, random_state=42)
LDA.fit(tfidf)
# Out:
# LatentDirichletAllocation(batch_size=128, doc_topic_prior=None,
#                           evaluate_every=-1, learning_decay=0.7,
#                           learning_method='batch', learning_offset=10.0,
#                           max_doc_update_iter=100, max_iter=10,
#                           mean_change_tol=0.001, n_components=20, n_jobs=None,
#                           perp_tol=0.1, random_state=42, topic_word_prior=None,
#                           total_samples=1000000.0, verbose=0)

# %%
for i,topic in enumerate(LDA.components_):
    print(f'Top 100 words for topic #{i}:')
    print([tfidf_vectorizer.get_feature_names()[i] for i in topic.argsort()[-100:]])
    print('\n')
# Out:
# Top 100 words for topic #0:
# ['gem', 'hidden', 'eg', 'significantly', 'end', 'part', 'check', 'closer', 'price', 'central', 'great', 'question', 'real', 'found', '40', 'clear', 'concrete', 'think', 'square', 'priced', 'station', 'fashionable', 'ok', 'expensive', 'rental', 'housing', 'min', 'happening', 'travel', 'walking', 'feel', 'house', 'lb', 'along', 'road', 'people', 'something', 'even', 'good', 'like', 'one', 'ive', 'train', 'near', 'sister', 'postcode', 'want', 'mixture', 'well', 'would', 'lively', 'life', 'safe', 'get', 'walk', 'right', 'pretty', 'pricey', 'bus', 'towards', 'year', 'far', 'much', 'flat', 'see', 'way', 'zone', 'born', 'suburb', 'know', 'reasonably', 'edge', 'border', 'minute', 'hole', 'must', 'help', '10', 'quite', 'around', 'estate', 'night', 'place', 'used', 'time', 'lived', 'hope', 'never', 'london', 'problem', 'cheaper', 'rough', 'nice', 'area', 'bit', 'live', 'stay', 'away', 'location2', 'location1']
#
#
# Top 100 words for topic #1:
# ['22', 'mainly', 'half', 'affluent', 'sure', 'street', 'absolute', 'much', 'borough', 'shopping', 'anywhere', 'combination', 'lovely', 'anyway', 'basically', 'natural', 'etc', 'park', 'country', 'o2', 'keep', 'nw', 'remember', 'great', 'full', 'stall', 'supermarket', 'village', 'plus', 'mostly', 'budget', 'nice', 'far', 'rest', 'people', 'time', 'would', 'compared', 'range', 'tourist', 'southeast', 'wrong', 'town', 'year', 'somewhere', 'safe', 'kind', 'brilliant', 'close', 'around', 'mate', 'history', 'small', 'centre', 'there', 'curry', 'bit', 'go', 'round', 'open', 'almost', 'quite', 'like', 'shop', 'think', 'good', 'offer', 'want', 'hamlet', 'however', 'tower', 'nothing', 'next', 'lived', 'dump', 'food', 'gorgeous', 'space', 'probably', 'part', 'fun', 'market', 'lot', 'also', 'really', 'whole', 'museum', 'try', 'live', 'expensive', 'place', 'bet', 'well', 'area', 'cheap', 'could', 'location2', 'london', 'location1', 'best']
#
#
# Top 100 words for topic #2:
# ['description', 'alos', 'large', 'poshest', 'maximum', 'hell', 'outside', 'fair', 'born', 'quite', 'go', 'boyfriend', 'probably', 'lived', 'found', 'crime', 'standard', 'school', 'vibrant', 'sureey', 'ptactical', 'private', 'le', 'house', 'visit', 'seem', 'consider', 'central', 'money', 'londoner', 'wont', 'run', 'advise', 'hill', 'nearly', 'number', 'see', 'sure', 'first', 'extensively', 'say', 'else', 'food', 'problem', 'people', 'lot', 'scared', 'staying', 'dodgy', 'agree', 'part', 'used', 'going', 'south', 'year', 'depends', 'postal', 'great', 'want', 'station', 'lucky', 'student', 'like', 'little', 'one', 'likely', 'centre', 'road', 'east', 'much', 'good', 'think', 'place', 'address', 'pretty', 'easily', 'able', 'around', 'street', 'worked', 'church', 'actually', 'stayed', 'area', 'find', 'moment', 'choice', 'end', 'indian', 'location2', 'living', 'rather', 'anywhere', 'london', 'would', 'mean', 'near', 'location1', 'live', 'love']
#
#
# Top 100 words for topic #3:
# ['safe', 'minute', 'feel', 'list', 'happy', 'long', 'south', 'knife', 'class', 'rate', 'interesting', 'take', 'etc', 'cheap', 'green', 'medium', 'example', 'recently', 'town', 'many', 'still', 'care', 'little', 'soon', 'essex', 'although', 'high', 'family', 'city', 'quieter', 'portugese', 'local', 'full', 'big', 'originally', 'extremely', 'river', 'type', 'price', 'pay', '15', 'best', 'say', 'better', 'bad', 'whereas', 'cinema', 'bar', 'prefer', 'got', 'borough', 'capital', 'first', 'pub', 'see', 'house', 'though', 'culture', 'grew', 'different', 'go', 'living', 'quite', 'budget', 'one', 'trendy', 'good', 'crime', 'inner', 'poor', 'visit', 'move', 'young', 'would', 'lot', 'moving', 'neighbourhood', 'really', 'favourite', 'working', 'safest', 'restaurant', 'like', 'great', 'shop', 'another', 'maybe', 'live', 'pretty', 'personally', 'part', 'expensive', 'london', 'think', 'place', 'try', 'area', 'nice', 'location2', 'location1']
#
#
# Top 100 words for topic #4:
# ['olympic', 'plenty', 'balance', 'cheap', 'best', 'cleaned', 'act', 'eye', 'swan', 'bedsit', 'pub', 'visa', 'man', 'direct', 'get', 'better', 'close', 'opinion', 'aswell', 'independent', 'boy', 'picadilly', 'fun', 'could', 'edgy', 'clubbing', 'right', 'commute', 'multi', 'honest', 'major', 'ride', 'square', 'rule', 'cheapest', 'cinema', 'need', 'metropolitan', 'rise', 'want', 'shopping', 'black', 'well', 'something', 'night', 'bangladeshi', 'rubbish', 'site', 'short', 'cultural', 'ideal', 'bit', 'pick', 'end', 'lot', 'check', 'center', 'along', 'dreadful', 'connect', 'quite', 'busy', 'near', 'towards', 'tube', 'market', 'going', 'run', 'nice', 'hand', 'road', 'minute', 'central', 'ever', 'around', 'really', 'also', 'boring', 'lovely', 'cost', 'station', 'choose', 'town', 'one', 'frequent', 'way', 'live', 'always', 'park', 'take', 'london', 'train', 'location2', 'would', 'underground', 'area', 'northern', 'line', 'go', 'location1']
#
#
# Top 100 words for topic #5:
# ['thing', 'another', 'far', 'park', 'though', 'developing', 'shopping', 'around', 'dont', 'bad', 'next', 'dar', 'found', 'close', 'bridge', 'restaurant', 'shop', 'still', 'lot', 'right', 'major', 'advantage', 'noise', 'cafe', 'back', 'al', 'public', 'probably', 'part', 'really', 'rough', 'hour', 'also', 'straight', 'one', 'friend', 'born', 'yes', 'north', 'centre', 'without', 'dull', 'national', 'excellent', 'normally', 'connected', 'getting', 'gone', 'bring', 'tourist', 'location', 'wembley', 'rock', 'side', 'dlr', 'think', 'called', 'night', 'would', 'well', 'longer', 'vibe', 'railway', 'corner', 'area', 'near', 'lane', 'overground', 'got', 'go', 'life', 'much', 'le', 'central', 'get', 'line', 'known', 'even', 'tube', 'come', 'agree', 'train', 'road', 'station', 'place', 'london', 'take', 'link', 'bus', 'transport', 'rail', 'live', 'good', 'posh', 'fine', 'location2', 'recommend', 'better', 'location1', 'great']
#
#
# Top 100 words for topic #6:
# ['renowned', 'warned', 'uk', 'budget', 'detail', 'additional', 'rest', 'peacock', 'free', 'impressed', 'adore', 'impossible', 'got', 'new', 'girl', 'club', 'mostly', 'truely', 'indian', 'economical', 'local', 'ever', 'boutique', 'opinion', 'map', 'limited', 'market', 'people', 'rapidly', 'inbetween', 'around', 'far', 'explore', 'knife', 'interesting', 'night', 'nw10', 'exact', 'work', 'class', 'travel', 'hand', 'compare', 'racing', 'edit', 'living', 'theatre', 'amount', 'london', 'place', 'direction', 'appreciated', 'part', 'like', 'super', 'stardom', 'similar', 'hotel', 'crime', 'live', 'ditto', 'hear', 'pleasantest', 'mile', 'make', 'directly', 'would', 'though', 'majority', 'block', 'spot', 'many', 'quirky', 'road', 'find', 'murder', 'bar', 'area', 'number', 'best', 'alot', 'sussex', 'go', 'rate', 'dangerous', 'suit', 'well', 'garden', 'higher', 'british', 'cheap', 'american', 'weekend', 'location2', 'thats', 'dirty', 'particularly', 'council', 'improving', 'location1']
#
#
# Top 100 words for topic #7:
# ['new', 'pick', 'browse', 'btw', 'youll', 'work', 'wo', 'scary', 'arty', 'suburb', 'tel', 'subway', 'train', '25', 'fav', 'great', 'dear', 'people', 'baby', 'chiswig', 'etc', 'park', 'still', 'well', 'get', 'good', 'borough', 'art', 'example', 'service', 'agree', 'pay', 'plague', 'regarded', 'club', 'council', '020', 'nice', 'gun', 'money', 'lived', 'everything', 'thrown', 'mean', 'except', 'thumb', 'prefer', 'give', 'bad', 'avoid', 'funky', 'like', 'coming', 'sometimes', 'line', 'band', 'living', 'place', 'understand', 'road', 'expensive', 'unless', 'nearest', 'amenity', 'right', 'mixed', 'certainly', 'night', 'around', 'know', 'three', 'safe', 'walking', 'generally', 'live', 'bit', 'north', 'south', 'central', 'distance', 'worst', 'misinformed', 'se', 'top', 'general', 'idea', 'sadly', 'lot', 'depends', 'quiet', 'quite', 'london', 'stop', 'station', 'location2', 'area', 'pleasant', 'close', 'tube', 'location1']
#
#
# Top 100 words for topic #8:
# ['variety', 'road', 'tell', 'drive', 'bus', 'england', 'nowadays', 'complex', 'excellent', 'scary', 'home', 'look', 'convenient', 'really', 'night', 'ie', 'used', 'massive', 'year', 'alot', 'form', 'indian', 'crime', 'website', 'quite', 'news', 'market', 'work', 'famous', 'life', 'apartment', 'willing', 'object', 'shopping', 'predominantly', 'probably', 'day', 'well', 'next', 'know', 'name', 'could', 'borough', 'find', 'bad', 'street', 'mind', 'might', 'ask', 'choose', 'nice', 'never', 'definitely', 'hi', '20', 'try', 'part', 'friend', 'large', 'place', 'lived', 'min', 'one', 'direct', 'enough', '30', 'point', 'told', 'station', 'best', 'go', 'im', 'get', 'safe', 'fast', 'mile', 'much', 'outer', 'enjoy', 'like', 'people', 'train', 'either', 'say', 'head', 'would', 'west', 'area', 'trouble', 'central', 'alternative', 'tube', 'rich', 'east', 'location2', 'london', 'live', 'south', 'money', 'location1']
#
#
# Top 100 words for topic #9:
# ['parliament', 'towards', 'horrible', 'time', 'grim', 'hard', 'actually', 'algate', 'month', 'close', 'ish', 'popular', 'two', 'cricket', 'trendy', 'comparison', 'square', 'hertfordshire', 'tower', 'cheaper', 'always', 'bank', 'one', 'north', 'living', 'borough', 'others', 'high', 'quiet', 'outskirt', 'afford', 'family', 'currently', 'nasty', 'specifically', 'much', 'looking', 'sort', 'known', 'side', 'fab', 'choice', 'right', 'celebrity', 'central', 'bexley', 'otherwise', 'street', 'still', 'great', 'noisy', 'affordable', 'quite', 'lot', 'make', 'level', 'west', 'part', 'best', 'overall', 'around', 'rough', 'even', 'mostly', 'apart', 'suburb', 'artist', 'good', 'lower', 'many', 'cross', 'house', 'crime', 'well', 'grotty', 'centre', 'thing', 'like', 'desirable', 'would', 'class', 'middle', 'south', 'expensive', 'course', 'nice', 'option', 'upmarket', 'little', 'okay', 'place', 'live', 'area', 'residential', 'location2', 'greater', 'yes', 'surrey', 'location1', 'london']
#
#
# Top 100 words for topic #10:
# ['wealthiest', 'kind', 'queen', 'website', 'drive', 'indie', 'stretch', '10', 'gather', 'suitable', 'interchange', 'zone', 'head', 'festival', 'link', 'rest', 'last', 'much', 'westminister', 'accommodation', 'learned', 'avoiding', 'location2', 'traditionally', 'soul', 'kent', 'find', 'east', 'take', 'event', 'range', 'well', 'record', 'nice', 'centre', 'indeed', 'suburb', 'cupboard', 'anyone', 'realise', 'fairly', 'side', 'sw4', 'regularly', 'cuz', 'going', 'expensive', 'market', 'local', 'drug', 'answer', 'se', 'hospital', 'messed', 'afro', 'visit', 'fancy', 'caribbean', 'safety', 'heavy', 'thank', 'larger', 'neighborhood', 'shop', 'place', 'uk', 'home', 'said', 'like', 'know', 'borough', 'try', 'crap', 'wide', 'close', 'cockney', 'sound', 'advance', 'many', 'might', 'page', 'poorer', 'district', 'born', 'pub', 'north', 'possible', 'help', 'notorious', 'character', 'restaurant', 'south', 'within', 'proper', 'area', 'london', 'bell', 'plenty', 'thinking', 'location1']
#
#
# Top 100 words for topic #11:
# ['finish', 'start', 'pretty', 'actually', 'irish', 'jew', 'range', 'rate', 'friendly', 'great', 'park', 'royal', 'light', 'coolest', 'looking', 'safe', 'life', 'friend', 'road', 'exclusive', 'downmarket', 'fairyland', 'kingsroad', 'child', 'might', 'paul', 'anyone', 'world', 'south', 'thanks', 'borough', 'real', 'much', 'e9', 'business', 'guess', 'enjoyed', 'north', 'john', 'suggestion', 'abouts', 'nice', 'bad', 'mine', 'reputation', 'accent', 'add', 'would', 'good', 'multicultural', 'probably', 'full', 'peaceful', 'living', 'thriving', 'get', 'advice', 'said', 'go', 'around', 'right', 'young', 'next', 'bit', 'offered', 'nightlife', 'asian', 'place', 'east', 'end', 'talking', 'near', 'rough', 'aware', 'many', 'always', 'really', 'think', 'live', 'person', 'part', 'vibrant', 'job', 'cockney', 'population', 'leafy', 'want', 'particular', 'come', 'like', 'people', 'london', 'cheapest', 'jewish', 'location2', 'community', 'large', 'dangerous', 'area', 'location1']
#
#
# Top 100 words for topic #12:
# ['since', 'many', 'street', 'favorite', 'going', 'lived', 'fairly', 'night', 'worth', 'site', 'station', 'centre', 'actually', 'term', 'inner', 'full', 'looking', 'beautiful', 'east', 'used', 'end', 'le', 'suburb', 'somewhere', 'check', 'move', 'start', 'venue', 'say', 'isnt', 'based', 'still', 'take', 'cheap', 'jubilee', 'could', 'fact', 'river', 'round', 'value', 'feel', 'however', 'school', 'music', 'south', 'need', 'right', 'alright', 'park', 'piccadilly', 'cafe', 'perhaps', 'want', 'better', 'well', 'cheaper', 'town', 'richmond', 'around', 'expensive', 'located', 'bit', 'called', 'tube', 'would', 'near', 'shopping', 'location', 'central', 'nearby', 'generally', 'might', 'lot', 'club', 'pub', 'part', 'load', 'line', 'etc', 'borough', 'either', 'north', 'live', 'restaurant', 'village', 'place', 'far', 'really', 'bar', 'london', 'west', 'nice', 'look', 'bad', 'like', 'area', 'also', 'location2', 'good', 'location1']
#
#
# Top 100 words for topic #13:
# ['nightlife', 'great', 'several', 'recently', 'downright', 'however', 'culture', 'zam', 'postcode', '1928', 'funzone', 'te', 'drug', 'thought', 'depeneds', 'seen', 'love', 'probably', 'taste', 'seems', 'record', 'even', 'living', 'expensive', 'driving', 'canadian', 'office', 'related', 'decently', 'tudor', 'music', 'dangerous', 'thing', 'little', 'lived', 'decision', 'kate', 'year', 'closer', 'moss', 'bad', 'whatever', 'right', 'guide', 'cheap', 'part', 'born', 'ridiculously', 'would', 'relatively', 'lack', 'lot', 'negative', 'keen', 'defo', 'place', 'alternative', 'possibly', 'offer', 'cheaper', 'idea', 'know', 'like', 'ticket', 'tends', 'much', 'mugged', 'recommend', 'find', 'people', 'high', 'used', 'entertainer', 'crime', 'price', 'looked', 'house', 'worse', 'summer', 'yeah', 'show', 'everyone', 'absolutely', 'seriously', 'common', 'anything', 'location2', 'least', 'think', 'get', 'kid', 'perfect', 'hang', 'street', 'london', 'beautiful', 'area', 'surrounding', 'live', 'location1']
#
#
# Top 100 words for topic #14:
# ['scenery', 'ago', 'college', 'moved', 'disgusting', 'university', 'living', 'borough', 'become', 'room', 'location', 'information', 'safest', 'born', 'year', 'currently', 'bit', 'young', 'dangerous', 'becoming', 'east', 'probably', 'would', 'safe', '000', 'want', 'aint', 'always', 'partner', 'road', 'leafy', 'way', 'decent', 'yeah', 'time', 'say', 'still', 'around', 'bedroom', 'long', 'best', 'professional', 'rate', 'per', 'example', 'go', 'nice', 'could', 'quite', 'share', 'lived', 'loved', 'used', 'liked', 'link', 'part', 'cheap', 'victoria', 'town', 'saying', 'people', 'cheapest', 'good', 'also', 'average', 'happens', 'lot', 'house', 'fairly', 'price', 'going', 'two', 'month', 'transport', 'near', 'prefer', 'like', 'high', 'nicer', 'expensive', 'buy', 'one', 'place', 'low', 'popular', 'property', 'nicest', 'know', 'london', 'rent', 'flat', 'affordable', 'live', 'crime', 'location2', 'afford', 'much', 'area', 'location1', 'lovely']
#
#
# Top 100 words for topic #15:
# ['lea', 'cheaper', 'since', 'visit', 'famous', 'enough', 'river', 'etc', 'happen', 'take', 'financial', 'cost', 'dark', 'one', 'actually', 'play', 'harrod', 'time', 'go', 'nothing', 'awesome', 'different', 'people', '14', 'great', 'minute', 'run', 'library', 'school', '16', 'ben', 'wise', 'good', 'connection', 'north', 'transportation', 'much', 'worry', 'bad', 'gatwick', 'like', 'ancient', 'buckingham', 'free', 'service', 'pricey', 'recommended', 'nice', 'open', 'transport', 'think', 'even', 'highly', 'around', 'house', 'palace', 'probably', 'every', 'two', 'going', 'close', 'west', 'train', 'spent', 'lot', 'space', 'may', 'however', 'big', 'old', 'last', 'generally', 'deprived', 'town', 'park', 'public', 'county', 'amazing', 'many', 'place', 'quite', 'day', 'pretty', 'also', 'feel', 'part', 'consider', 'airport', 'live', 'living', 'year', 'green', 'safer', 'location2', 'area', 'lived', 'kent', 'london', 'safe', 'location1']
#
#
# Top 100 words for topic #16:
# ['museum', 'probably', 'different', 'important', 'word', 'roughest', 'wonderful', 'two', 'old', 'proximity', 'busy', 'includes', 'link', 'lively', 'lot', 'see', 'recommend', 'rough', 'upper', 'lived', 'le', 'suburb', 'afford', 'dump', 'commute', 'near', 'rather', 'sorry', 'really', 'stuff', 'night', 'pretty', 'part', 'far', 'stabbed', 'borough', 'one', 'historic', 'day', 'street', 'best', 'honest', 'life', 'clean', 'drink', 'quiet', 'well', 'garden', 'know', 'worth', 'go', 'great', 'move', 'young', 'cheap', 'modern', 'side', 'river', 'id', 'believe', 'ghetto', 'central', 'south', 'mainly', 'people', 'considered', 'especially', 'bit', 'also', 'quite', 'better', 'cosmopolitan', 'family', 'world', 'may', 'suburban', 'luck', 'thames', 'eat', 'around', 'nice', 'mentioned', 'good', 'say', 'though', 'coming', 'london', 'definitely', 'expensive', 'somewhere', 'cool', 'live', 'place', 'looking', 'like', 'area', 'suggest', 'location2', 'would', 'location1']
#
#
# Top 100 words for topic #17:
# ['hill', 'look', 'flight', 'trust', 'lambeth', 'think', 'nearer', 'clanricarde', 'go', 'class', 'taxi', 'priced', 'slough', 'borough', 'move', 'quality', 'dlr', 'store', 'one', 'worth', 'firstly', 'umm', 'upper', 'biggest', 'bridge', 'white', 'safest', 'nicest', 'work', 'used', 'reading', 'safe', '10th', 'decent', 'market', 'plenty', 'gotta', 'close', 'main', 'around', 'easy', 'reach', 'youd', 'expensive', 'nicer', 'lol', 'beautiful', 'somewhere', 'green', 'central', 'local', 'month', 'term', 'zone', 'route', 'communication', 'country', 'middle', 'nice', 'trendier', 'new', 'railway', 'need', 'tube', 'would', 'school', 'wouldnt', 'attraction', 'great', 'opinion', 'feel', 'bus', 'also', 'surrounding', 'get', 'village', 'station', 'garden', 'different', 'alot', 'afraid', 'location2', 'fantastic', 'within', 'outside', 'quite', 'road', 'want', 'way', 'dont', 'good', 'place', 'thought', 'like', 'area', 'long', 'essex', 'live', 'london', 'location1']
#
#
# Top 100 words for topic #18:
# ['building', 'life', 'se1', 'little', 'relatively', 'close', 'stamford', 'safest', 'went', 'system', 'head', 'like', 'day', '18', 'south', 'price', 'ago', 'baker', 'take', 'safe', 'north', 'easier', 'therefore', 'new', 'n7', 'solid', 'stick', 'list', 'seen', 'bridge', 'imagine', 'sunday', 'perfectly', 'fan', 'within', 'living', 'expect', 'link', 'try', 'much', 'bus', 'although', 'uni', 'seems', 'shop', 'literally', 'surrey', 'pretty', 'housing', 'near', 'work', 'know', 'nicer', 'morning', 'bit', 'line', 'reason', 'district', 'lot', 'would', 'commute', 'great', 'cheaper', 'say', 'go', 'nice', 'time', 'lived', 'market', 'quite', 'suburb', 'hometown', 'part', 'train', 'good', 'getting', 'especially', 'also', 'reasonable', 'rent', 'probably', 'st', 'going', 'place', 'slightly', 'access', 'one', 'year', 'sw', 'walk', 'live', 'decent', 'location2', 'central', 'get', 'area', 'london', 'easy', 'expensive', 'location1']
#
#
# Top 100 words for topic #19:
# ['map', 'pricey', 'located', 'spend', 'yep', 'another', 'prostitution', 'according', 'road', 'mall', 'born', 'bit', 'long', 'market', 'near', 'somewhere', 'right', 'used', 'great', 'comfortable', 'friend', 'many', 'borderline', 'reputation', 'lot', 'easy', 'journey', 'shop', 'huge', 'station', 'life', 'classy', 'train', 'mate', 'either', 'sure', 'due', 'yet', 'thing', 'love', 'know', 'regent', 'super', 'high', 'moving', 'others', 'however', 'problem', 'met', 'old', 'central', 'rest', 'found', 'highest', 'westfield', 'place', 'oxford', 'easily', 'even', 'major', 'minute', 'drug', 'around', 'big', 'accessible', 'ride', '30', 'affluent', 'said', 'lovely', 'couple', 'close', 'would', 'crime', 'go', 'rate', 'people', 'true', 'year', 'friendly', 'nice', 'though', 'felt', 'unsafe', 'lived', 'also', 'main', 'street', 'area', 'live', 'shopping', 'london', 'heard', 'never', 'location2', 'one', 'centre', 'ok', 'location1', 'avoid']

# %%
from sklearn.decomposition import NMF

nmf = NMF(n_components=20, random_state=42)
nmf.fit(tfidf )
# Out:
# NMF(alpha=0.0, beta_loss='frobenius', init=None, l1_ratio=0.0, max_iter=200,
#     n_components=20, random_state=42, shuffle=False, solver='cd', tol=0.0001,
#     verbose=0)

# %%
for i,topic in enumerate(nmf.components_):
    print(f'Top 100 words for topic #{i}:')
    print([tfidf_vectorizer.get_feature_names()[i] for i in topic.argsort()[-100:]])
    print('\n')
aspect_file = open(output_dir + '/aspect.log{}'.format(args.aspect_size), 'wt', encoding='utf-8')
# Out:
# Top 100 words for topic #0:
# ['borderline', 'alternative', 'decently', 'leafy', 'perhaps', 'mixed', 'opt', 'way', 'par', 'based', 'close', 'train', 'nowadays', 'fact', 'roughest', 'funky', 'agree', 'load', 'jusy', 'alternatively', 'gorgeous', 'reasonably', 'example', 'first', 'head', 'personally', 'min', 'chinese', 'next', 'crime', 'journey', 'millionaire', 'friend', 'beautiful', 'excellent', 'gone', 'hamlet', 'inner', 'posh', 'suggested', 'similar', 'feel', 'dump', 'reach', 'lane', 'river', 'mentioned', 'fav', 'rest', 'little', 'mths', 'case', 'willing', 'garden', 'near', 'safest', 'complex', 'located', 'either', 'nearer', 'worst', 'recommended', 'top', 'take', 'safe', 'especially', 'road', 'called', 'bet', 'move', 'anywhere', 'considered', 'quiet', 'richmond', 'born', 'living', 'direct', 'safer', 'look', 'might', 'affordable', 'pleasant', 'working', 'recommend', 'still', 'ok', 'flat', 'far', 'etc', 'dangerous', 'right', 'cheaper', 'stay', 'surrey', 'borough', 'best', 'away', 'avoid', 'location1', 'location2']
#
#
# Top 100 words for topic #1:
# ['cuz', 'type', 'hertfordshire', 'come', 'upmarket', 'especially', 'mum', 'se', 'perfectly', 'think', 'ever', 'financial', 'far', 'ie', 'website', 'although', 'wouldnt', 'beautiful', 'worked', 'depends', 'close', 'estate', 'example', 'amazing', 'apartment', 'opinion', 'always', 'old', 'house', 'pit', 'well', 'end', 'quite', 'without', 'edge', 'bridge', 'wanted', 'mainly', 'born', '14', 'north', 'honest', 'lot', 'next', 'tempted', 'family', 'year', 'music', 'venue', 'tell', 'perfect', 'river', 'considered', 'brilliant', 'problem', 'londoner', 'artist', 'really', 'say', 'borderline', 'community', 'cheaper', 'feel', 'border', 'lol', 'rock', 'id', 'prefer', 'need', 'hi', 'south', 'choose', 'friend', 'right', 'safe', 'essex', 'currently', 'work', 'mile', 'personally', 'grotty', 'around', 'never', 'know', 'council', 'money', 'pretty', 'ok', 'could', 'love', 'rich', 'rather', 'people', 'moment', 'afford', 'want', 'location1', 'used', 'near', 'live']
#
#
# Top 100 words for topic #2:
# ['know', 'highest', 'notorious', 'rate', 'realise', 'working', 'green', 'space', 'general', 'resident', 'commuter', 'map', 'name', 'way', 'england', 'called', 'get', 'except', 'zone', 'probably', 'start', 'nearer', 'mile', 'attraction', 'still', 'based', 'address', 'whole', 'living', 'idea', 'thames', 'moved', 'easily', 'walk', 'surrey', 'rent', 'thinking', 'form', 'mentioned', '1965', 'outside', 'every', 'afraid', 'southeast', 'since', 'access', 'hometown', 'old', 'actually', 'affordable', 'new', 'location', 'outskirt', 'course', 'road', 'originally', 'cheap', 'richmond', 'southwest', 'right', 'middle', 'time', 'bexley', 'county', 'within', 'two', 'different', 'village', 'come', 'district', 'minute', 'commute', 'far', 'travel', 'best', 'close', 'yes', 'located', 'end', 'easy', 'cheapest', 'nicest', 'outer', 'moving', 'sw', 'se', 'centre', 'kent', 'east', 'inner', 'north', 'suburb', 'location1', 'one', 'greater', 'borough', 'west', 'central', 'south', 'london']
#
#
# Top 100 words for topic #3:
# ['market', 'northwest', 'otherwise', 'rent', 'professional', 'university', 'richmond', 'immigrant', 'biggest', 'comprimise', 'opinion', 'inbetween', 'cheaper', 'wo', 'sw', 'brother', 'even', 'house', 'northern', 'shithole', 'problem', '15', 'touch', 'ie', 'full', 'help', 'border', 'street', 'link', 'quiet', 'kno', 'pricey', 'taste', 'true', 'short', 'pocket', 'cafe', 'nearby', 'nw', 'cofe', 'change', 'price', 'obviously', 'across', 'alos', 'south', 'thames', 'worth', 'corridor', 'day', 'plenty', 'month', 'lot', 'center', 'posh', 'n1', 'bith', 'cross', 'school', 'overall', 'min', 'neighbourhood', 'paced', 'another', 'hang', 'check', 'hope', 'lb', 'close', 'family', 'flower', 'stuff', 'young', 'borough', 'centre', 'travel', 'green', 'river', 'thought', 'west', 'bar', 'reasonable', 'avoid', 'though', 'pub', 'cheap', 'north', 'near', 'suburb', 'restaurant', 'town', 'far', 'park', 'shop', 'pretty', 'bit', 'quite', 'really', 'location1', 'nice']
#
#
# Top 100 words for topic #4:
# ['others', 'council', 'suggest', 'suburban', 'rental', 'general', 'small', 'run', 'population', 'diverse', 'round', 'postcode', 'rise', 'job', 'professional', 'people', 'sort', 'interesting', 'find', 'beautiful', 'idea', 'read', 'unsafe', 'family', 'say', 'starting', 'visit', 'mostly', 'indian', 'look', 'trendy', 'could', 'road', 'property', 'green', 'loved', 'muslim', 'specifically', 'fairly', 'low', 'upmarket', 'housing', 'desirable', 'whole', 'busy', 'get', 'mainly', 'mean', 'multi', 'rate', 'class', 'work', 'different', 'estate', 'house', 'safer', 'cultural', 'quiet', 'feel', 'within', 'deprived', 'dangerous', 'found', 'many', 'affluent', 'avoid', 'another', 'coming', 'lively', 'affordable', 'generally', 'know', 'poor', 'jewish', 'want', 'need', 'young', 'nicest', 'looking', 'pretty', 'think', 'location1', 'residential', 'surrounding', 'large', 'high', 'rough', 'really', 'lot', 'lovely', 'best', 'probably', 'quite', 'pleasant', 'crime', 'cheapest', 'safe', 'one', 'around', 'area']
#
#
# Top 100 words for topic #5:
# ['barfly', 'fusellier', 'going', 'late', 'website', 'college', 'still', 'amenties', 'ancient', 'term', 'bless', 'park', 'uni', 'warned', 'relax', 'decent', 'family', 'quality', 'share', 'e17', 'n12', 'transportation', 'affordable', 'flat', 'quiet', 'whereas', 'cinema', 'swan', 'young', 'empire', 'add', 'next', 'central', 'finding', 'general', 'service', 'newcomer', 'sw4', 'communication', 'surrounded', 'easy', 'spot', 'well', 'maybe', 'generally', 'price', 'night', 'fairly', 'nearby', 'access', 'trendy', 'facility', 'lucky', 'shabby', 'centre', 'though', 'safe', 'neighbourhood', 'amenity', 'music', 'venue', 'rest', 'told', 'nightlife', 'excellent', 'bus', 'got', 'cafe', 'range', 'bet', 'agree', 'close', 'start', 'always', 'market', 'public', 'local', 'connection', 'quite', 'etc', 'location', 'load', 'lot', 'rail', 'pretty', 'club', 'town', 'choice', 'pub', 'might', 'school', 'shop', 'bar', 'link', 'luck', 'restaurant', 'location1', 'shopping', 'transport', 'good']
#
#
# Top 100 words for topic #6:
# ['jewish', 'harrod', 'house', 'probably', 'decent', 'im', 'may', 'crime', 'world', 'lane', 'alternative', 'cost', 'located', 'hole', 'bell', 'definitely', 'called', 'tourist', 'mixture', 'beautiful', 'stay', 'always', 'next', 'high', 'price', 'end', 'around', 'thing', 'nearby', 'leafy', 'see', 'new', 'nicer', 'move', 'enjoy', 'opinion', 'day', 'recommend', 'moving', 'generally', 'heard', 'alot', 'suburb', 'market', 'long', 'agree', 'walk', 'coming', 'say', 'come', 'visit', 'posh', 'park', 'dangerous', 'cockney', 'going', 'mean', 'time', 'big', 'head', 'near', 'village', 'little', 'community', 'actually', 'side', 'large', 'full', 'way', 'museum', 'lot', 'people', 'however', 'north', 'shopping', 'cool', 'prefer', 'okay', 'safe', 'take', 'east', 'surrey', 'well', 'kent', 'though', 'living', 'born', 'even', 'cheap', 'road', 'right', 'fine', 'ok', 'street', 'look', 'avoid', 'close', 'lovely', 'love', 'location1']
#
#
# Top 100 words for topic #7:
# ['load', 'seems', 'old', 'moss', 'currently', 'park', 'tawhid', 'observation', 'caledonian', 'born', 'vilagey', 'small', 'choice', 'use', 'residential', 'street', 'se', 'clean', 'unfortunately', 'looking', 'along', 'especially', 'real', 'sure', 'suburban', 'overly', 'commute', 'populated', 'reading', 'university', 'stay', 'comprimise', 'say', 'mixed', 'youre', 'within', 'contrast', 'desirable', 'seriously', 'therefore', 'town', 'apartment', 'guess', 'river', 'nearby', 'useful', 'vibrant', 'tennis', 'well', 'temporarily', 'get', 'slough', 'ramo', 'view', 'many', 'includes', 'unclassy', 'budget', 'sound', 'choose', 'living', 'wanna', 'outskirt', 'lower', 'plague', 'medium', 'full', 'check', 'neighbourhood', 'rather', 'level', 'type', 'move', 'city', 'safer', 'trendy', 'kind', 'still', 'beautiful', 'prefer', 'want', 'said', 'particularly', 'cool', 'coming', 'however', 'feel', 'etc', 'going', 'leafy', 'country', 'people', 'dont', 'might', 'bit', 'location1', 'really', 'village', 'somewhere', 'like']
#
#
# Top 100 words for topic #8:
# ['aswell', 'trendy', 'whereas', 'dump', 'listed', 'offered', 'garden', 'grow', 'found', 'think', 'thought', 'drinking', 'hope', 'others', 'concerned', 'rough', 'ever', 'big', 'budget', 'snobbiest', 'brilliant', 'club', 'ruffest', 'need', 'except', 'capital', 'honest', 'since', 'alos', 'lively', 'dodgy', 'wonderful', 'entertainer', 'fantastic', 'help', 'community', 'word', 'seriously', 'middx', 'whole', 'see', 'life', 'find', 'course', 'bachelor', 'however', 'small', 'fab', '25', 'rate', 'level', 'grew', 'fairly', 'get', 'lower', 'stay', 'bet', 'messed', 'craziest', 'rent', 'hang', 'favorite', 'food', 'amazing', 'world', 'well', 'large', 'particular', 'decent', 'affordable', 'must', 'another', 'plenty', 'nicest', 'safe', 'start', 'visit', 'heard', 'drink', 'called', 'desirable', 'bar', 'market', 'probably', 'etc', 'low', 'surrey', 'looking', 'location1', 'one', 'cool', 'cheap', 'lot', 'crime', 'favourite', 'eat', 'safest', 'lovely', 'best', 'place']
#
#
# Top 100 words for topic #9:
# ['dunno', 'centre', 'wouldnt', 'local', 'thats', 'thank', 'become', 'outwards', 'advance', 'preparing', 'reluctantly', 'way', 'bet', 'mostly', 'buy', 'snobbery', 'scale', 'wonderful', 'mentioned', 'humpty', 'prejudiced', 'cheerful', 'school', 'cemetery', 'otherwise', 'certainly', 'swathe', 'okay', '15mins', 'albeit', 'trendier', 'bank', 'flat', 'negative', 'kind', 'world', 'highly', 'cosmopolitan', 'desirable', 'next', 'range', 'could', 'police', 'open', 'house', 'affordable', 'apartment', 'everything', 'gorgeous', 'ridiculously', 'budget', 'busy', 'rich', 'pleasant', 'cheaper', 'upmarket', 'housing', 'lol', 'close', 'village', 'move', 'living', 'reason', 'people', 'however', 'slightly', 'rent', 'n7', 'solid', 'extremely', 'bit', 'proper', 'saying', 'definitely', 'afford', 'worth', 'central', 'offer', 'town', 'long', 'either', 'nicer', 'space', 'bloody', 'ok', 'posh', 'le', 'still', 'getting', 'especially', 'yes', 'location', 'lot', 'though', 'probably', 'well', 'location1', 'one', 'quite', 'expensive']
#
#
# Top 100 words for topic #10:
# ['farthest', 'boxy', 'dirty', 'away', 'opinion', 'may', 'finding', 'rochester', 'object', 'luck', 'hardly', 'appreciated', 'million', 'could', 'supply', 'mind', 'comprimise', 'buy', 'must', 'region', 'thames', 'feel', 'know', 'gorg', 'southeast', 'staying', 'safety', '22', 'anyone', 'sway', 'alright', 'direct', 'able', 'snobbiest', 'ideal', 'mate', 'walking', 'call', 'peaceful', 'flat', 'consider', 'value', 'likely', 'preference', 'better', 'bet', 'well', 'option', 'agree', 'run', 'think', 'though', 'upper', 'cost', 'two', 'many', 'okay', 'towards', 'visit', 'rent', 'big', 'worked', 'term', 'rather', 'close', 'cheapest', 'either', 'perhaps', 'first', 'pick', 'really', 'house', 'going', 'extensively', 'far', 'maybe', 'worth', 'list', 'imagine', 'want', 'never', 'budget', 'enough', 'living', 'choose', 'somewhere', 'best', 'afford', 'personally', 'looking', 'look', 'location1', 'definitely', 'choice', 'money', 'around', 'recommend', 'say', 'suggest', 'would']
#
#
# Top 100 words for topic #11:
# ['rough', 'microbrewery', 'beer', 'brew', 'albert', 'nearby', 'thats', 'capital', 'option', 'edgy', 'gorgeous', 'white', 'humpty', 'went', 'round', 'st', 'fact', 'reasonable', 'uk', 'pancras', 'canada', 'see', 'sell', 'connection', 'classical', 'boundary', 'park', 'game', 'quiete', 'mansion', 'whats', 'visit', 'long', 'cross', 'find', 'might', 'depeneds', 'nowadays', 'check', 'kent', 'cosmopolitan', 'student', 'financial', 'rail', 'tempted', 'lively', 'class', 'site', 'n1', 'regent', 'market', 'link', 'number', 'got', 'worth', 'next', 'vibrant', 'two', 'national', 'major', 'house', 'highly', 'mall', 'train', 'location', 'centre', 'worked', 'home', 'share', 'service', 'may', 'le', 'museum', 'going', 'north', 'bar', 'lived', 'popular', 'remember', 'river', 'slightly', 'affluent', 'cool', 'town', 'say', 'restaurant', 'big', 'lot', 'flat', 'consider', 'take', 'lovely', 'south', 'could', 'bit', 'location1', 'cheaper', 'west', 'look', 'also']
#
#
# Top 100 words for topic #12:
# ['profile', 'sell', 'another', 'tesco', 'lazy', 'prefer', 'always', 'personally', 'mainly', 'site', 'culture', 'coming', 'imagine', 'neighbour', 'almost', 'heap', 'greenery', 'stuff', 'regularly', 'food', 'quiet', 'along', 'vibe', 'day', 'edge', 'consider', 'local', 'lambeth', 'east', 'indie', 'praise', 'sing', 'film', 'gig', 'cinema', 'wharf', 'band', 'taken', 'link', 'people', 'load', 'offer', 'public', 'plus', 'sw', 'gabriel', 'common', 'surrey', 'everywhere', 'excellent', 'side', 'moment', 'lively', 'care', 'get', 'access', 'young', 'preserve', 'kid', 'wonderful', 'end', 'amenity', 'theatre', 'etc', 'famous', 'curry', 'overground', 'house', 'nightlife', 'family', 'come', 'green', 'connection', 'bangladeshi', 'posh', 'stay', 'cafe', 'sunday', 'park', 'got', 'street', 'poor', 'night', 'known', 'bar', 'afford', 'well', 'yes', 'transport', 'lot', 'really', 'life', 'location', 'pub', 'shop', 'market', 'restaurant', 'location1', 'think', 'great']
#
#
# Top 100 words for topic #13:
# ['angel', 'least', '45', 'network', 'right', 'service', 'find', 'need', 'connects', 'anywhere', 'metropolitan', 'next', 'via', 'stayed', 'bar', 'national', 'le', 'distance', 'might', 'victoria', 'walking', 'hill', '15', 'connect', 'commute', 'pub', 'journey', 'time', 'park', 'excellent', 'district', 'etc', 'work', '40', 'within', 'shop', '35', 'still', 'ten', 'going', 'route', 'zone', 'mainline', 'reach', 'three', 'bakerloo', 'bridge', 'look', 'close', 'dlr', 'major', 'road', '10', 'night', 'lot', 'served', 'overground', 'easily', 'nearest', 'away', 'generally', 'connection', 'restaurant', 'connected', 'access', 'frequent', 'railway', 'jubilee', 'around', 'min', 'link', 'centre', 'direct', 'main', 'fast', 'street', 'ride', 'transport', '30', 'rail', 'location1', 'walk', 'piccadilly', 'well', 'cheaper', 'northern', 'one', 'underground', 'stop', 'easy', 'near', 'take', 'minute', 'get', 'bus', 'central', 'train', 'line', 'station', 'tube']
#
#
# Top 100 words for topic #14:
# ['corner', 'eight', 'though', '30', 'using', 'fun', 'feel', 'family', 'late', 'near', 'moved', '12', 'precise', 'lot', '18', 'hi', 'sister', 'hey', 'attacked', 'adored', 'anywhere', '49', 'get', 'else', 'walk', 'many', 'spend', 'cheerful', 'child', 'whole', 'small', 'public', 'safe', 'thing', 'love', 'transport', 'crime', 'road', '16', 'hope', 'help', 'ha4', 'night', 'loved', 'se', '34', 'stabbed', '82', 'definitely', 'yr', 'almost', 'bother', 'born', 'first', '11', 'without', 'flat', 'able', 'nan', 'witnessed', 'ive', 'friend', 'border', 'used', 'friendly', '10', 'stay', 'away', 'living', '20', 'six', 'one', 'safest', 'past', 'day', 'liked', 'really', 'unsafe', 'well', '25', 'lovely', 'village', 'people', 'know', 'found', 'couple', 'felt', 'ago', 'two', 'last', 'time', 'trouble', 'location1', 'month', 'problem', 'old', 'life', 'never', 'year', 'lived']
#
#
# Top 100 words for topic #15:
# ['become', 'le', 'rate', 'looking', 'condition', 'answer', 'line', 'went', 'compared', 'enough', 'mayb', 'rest', 'stabbings', 'online', 'sepaerated', 'explain', 'reason', 'nothing', 'seven', 'add', 'cockney', 'kind', 'infact', 'rundown', 'transport', 'friend', 'move', 'recent', 'border', 'violent', 'wit', 'alot', 'upmarket', 'pretty', 'general', 'coming', 'money', 'happens', 'lot', 'different', 'even', 'ok', 'east', 'developing', 'amazing', 'vibrant', 'come', 'rap', 'use', 'met', 'considered', 'stabbed', 'getting', 'mile', 'diverse', 'night', 'sure', 'thats', 'everywhere', 'artist', 'house', 'direct', 'rough', 'happen', 'something', 'unfortunately', 'want', 'beautiful', 'might', 'always', 'personally', 'although', 'depends', 'everyone', 'check', 'alright', 'news', 'ai', 'many', 'worry', 'heard', 'mind', 'mostly', 'aint', 'friendly', 'living', 'find', 'used', 'cheap', 'avoid', 'quite', 'crime', 'reputation', 'isnt', 'people', 'location1', 'think', 'really', 'either', 'bad']
#
#
# Top 100 words for topic #16:
# ['culture', 'property', 'olympics', 'friendly', 'short', 'find', 'sk', 'thameside', 'around', 'noth', 'curry', 'wealthy', 'convenience', 'council', 'studio', 'fun', 'tend', 'open', 'within', 'generally', 'min', '2012', 'coming', 'better', 'accomopdation', 'borough', 'commuter', 'close', 'pocket', 'professional', 'commute', 'quieter', 'flat', 'indianan', 'travel', 'safe', 'see', 'load', 'feel', 'got', 'lot', 'scattered', 'shopping', 'plenty', 'please', 'ignorant', 'fit', 'south', 'nw10', '15', 'transport', 'young', 'get', 'capital', 'might', 'bothered', 'away', 'night', 'seen', 'far', 'bar', 'stretch', 'favourite', 'fairly', 'already', 'fancy', 'harlequin', 'luck', 'trendy', 'popular', 'alternatively', 'town', 'perhaps', 'decent', 'thinking', 'keep', 'stay', 'hometown', 'living', 'searching', 'west', 'affordable', 'north', 'money', 'nearby', 'link', 'quite', 'end', 'round', 'maybe', 'looking', 'budget', 'centre', 'want', 'location1', 'cheap', 'well', 'somewhere', 'could', 'try']
#
#
# Top 100 words for topic #17:
# ['early', 'community', 'mate', 'pleasant', 'certain', 'total', 'fine', 'lol', 'enjoy', 'willing', 'may', 'bexley', 'county', 'across', 'peace', 'sound', 'danger', 'alot', 'named', 'snobbery', 'hamlet', 'jewish', 'correctly', 'given', 'richmond', 'form', 'said', 'asked', 'always', 'large', 'transport', 'merely', 'fairly', 'warned', 'dicey', 'major', 'rent', 'rougher', 'poorer', 'noticed', 'coming', 'ago', 'traditionally', 'ptactical', 'sureey', 'known', 'particularly', 'maybe', 'absolute', 'small', 'relatively', 'depeneds', 'enough', 'weekend', 'variety', 'uni', 'public', 'poor', 'estate', 'contrast', 'grew', 'administratively', 'actually', 'outer', 'prestigious', 'mean', 'around', 'whole', 'depends', 'certainly', 'going', 'crime', 'cheapest', 'street', 'really', 'safest', 'kent', 'unfortunately', 'time', 'gorgeous', 'still', 'worst', 'however', 'high', 'greater', 'pricey', 'town', 'although', 'village', 'little', 'feel', 'rural', 'essex', 'location1', 'many', 'safe', 'rough', 'borough', 'quite', 'part']
#
#
# Top 100 words for topic #18:
# ['risky', 'st', 'tottenhom', 'exhibition', 'interchange', 'punk', 'budget', 'oxford', 'nightlife', 'someone', 'long', 'elaborate', 'may', 'crime', 'arsenal', 'hour', 'hotel', 'stall', 'compromise', 'suddenly', 'stay', 'art', 'sunday', 'warned', 'beals', 'main', 'similarly', 'late', 'nearby', 'restaurant', 'comparitively', 'town', 'contrary', 'often', 'regularly', 'rough', 'quite', 'etc', 'anywhere', 'somewhere', 'problem', 'willing', 'club', 'wanted', 'unique', 'partying', 'even', 'day', 'essex', 'outside', 'end', 'need', 'advice', 'cinema', 'get', 'fan', 'reckon', 'transforming', 'preference', 'find', 'reasonable', 'excellent', 'could', 'time', 'every', 'fun', 'supermarket', 'way', 'shop', 'posh', 'near', 'central', 'bar', 'option', 'talking', 'never', 'personally', 'wrong', 'particularly', 'dont', 'east', 'load', 'price', 'see', 'many', 'bus', 'always', 'though', 'cheap', 'afford', 'another', 'shopping', 'north', 'west', 'want', 'night', 'location1', 'centre', 'south', 'go']
#
#
# Top 100 words for topic #19:
# ['number', 'nan', 'transport', 'blackfriar', 'le', 'history', 'safer', 'dangerouse', 'publicity', 'got', 'scary', 'richer', 'racism', 'shop', 'feel', 'fine', 'considered', 'offence', 'expect', 'chav', 'bet', 'others', 'dead', 'idea', 'going', 'beautiful', 'honest', 'although', 'yeah', 'alot', 'reputation', 'awkward', 'green', 'yes', 'best', 'little', 'nearby', 'personally', 'one', 'value', 'day', 'county', 'hope', 'kid', 'couple', 'guess', 'dodgy', 'suburb', 'deal', 'doesnt', 'anywhere', 'maybe', 'make', 'find', 'nicest', 'pricer', 'there', 'help', 'though', 'sometimes', 'essex', 'side', 'dlr', 'tourist', 'crime', 'generally', 'night', 'used', 'money', 'away', 'probably', 'lot', 'spend', 'central', 'dump', 'living', 'pricey', 'looking', 'quite', 'prefer', 'still', 'getting', 'life', 'thing', 'depends', 'rough', 'safe', 'get', 'way', 'location1', 'cheaper', 'nicer', 'even', 'pretty', 'far', 'know', 'think', 'bit', 'better', 'much']

# %%
# Initialize NMF
nmf = NMF(init='random', n_components=20, random_state=0)
W = nmf.fit_transform(tfidf)
H = nmf.components_

# %%
W.shape, H.shape
# Out:
# ((3, 15), (15, 15))

# %%
# Out:
# array([[2.41518112e-01, 0.00000000e+00, 2.31370350e-01, 0.00000000e+00,
#         2.27141613e-01, 1.01119793e-01, 0.00000000e+00, 2.05122031e-01,
#         0.00000000e+00, 1.12843727e-01, 0.00000000e+00, 2.04677398e-01,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 6.93254447e-02, 0.00000000e+00, 1.95679946e-08,
#         0.00000000e+00, 2.95510016e-01, 1.65555818e-01, 0.00000000e+00,
#         1.39262767e-01, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         2.38997358e-01, 0.00000000e+00, 2.62081348e-01],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 6.44660660e-01,
#         0.00000000e+00, 1.28770330e-01, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 7.85489175e-01, 0.00000000e+00,
#         0.00000000e+00, 8.23709222e-01, 0.00000000e+00],
#        [0.00000000e+00, 3.80942275e-01, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 1.23185069e-02, 3.62746894e-01, 0.00000000e+00,
#         3.54105994e-01, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         3.48743140e-01, 0.00000000e+00, 3.08511799e-01],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 5.12683139e-02, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [5.48914268e-01, 0.00000000e+00, 7.47785593e-01, 0.00000000e+00,
#         6.34502900e-01, 0.00000000e+00, 0.00000000e+00, 8.15912218e-01,
#         0.00000000e+00, 1.12713795e+00, 0.00000000e+00, 7.82197259e-01,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 1.21584390e-01, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [2.24668065e-01, 0.00000000e+00, 8.99394525e-02, 0.00000000e+00,
#         1.74411609e-01, 1.38242062e-01, 0.00000000e+00, 2.06423695e-01,
#         0.00000000e+00, 5.40128326e-02, 0.00000000e+00, 1.86048794e-01,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [2.03092854e-02, 0.00000000e+00, 1.04051009e-15, 0.00000000e+00,
#         5.27094290e-02, 1.46511452e-02, 0.00000000e+00, 1.52024655e-01,
#         0.00000000e+00, 2.54884048e-02, 0.00000000e+00, 9.70587106e-04,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [7.62663707e-02, 0.00000000e+00, 3.36891513e-02, 0.00000000e+00,
#         1.18673140e-01, 1.52047695e-01, 0.00000000e+00, 3.18648298e-02,
#         0.00000000e+00, 2.49177434e-01, 0.00000000e+00, 1.15098794e-01,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 1.85318209e-01, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 6.47868752e-02, 1.59585552e-01, 0.00000000e+00,
#         1.42226356e-01, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         1.28397607e-01, 0.00000000e+00, 1.36354938e-01],
#        [8.59553299e-02, 0.00000000e+00, 1.57256195e-01, 0.00000000e+00,
#         3.22644497e-02, 9.37425328e-02, 0.00000000e+00, 8.72245231e-02,
#         0.00000000e+00, 1.05284916e-01, 0.00000000e+00, 8.17863226e-02,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 3.28090631e-01,
#         0.00000000e+00, 1.73818103e-01, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 2.29795880e-01, 0.00000000e+00,
#         0.00000000e+00, 2.10564656e-01, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 2.20215316e-01,
#         0.00000000e+00, 3.75823521e-02, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 1.64604553e-01, 0.00000000e+00,
#         0.00000000e+00, 2.84960520e-02, 0.00000000e+00],
#        [0.00000000e+00, 3.22925058e-02, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 4.17426600e-02, 1.73266158e-03, 0.00000000e+00,
#         2.29995454e-01, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         4.71936194e-02, 0.00000000e+00, 1.56851638e-01]])

# %%
tfidf_vectorizer.vocabulary_.keys()
# Out:
# dict_keys(['location1', 'transforming', 'price', 'go', 'along', 'lot', 'electronics', 'shop', 'independent', 'one', 'ten', 'min', 'direct', 'tube', 'location2'])

# %%
terms = [""] * len(tfidf_vectorizer.vocabulary_)
terms
# Out:
# ['', '', '', '', '', '', '', '', '', '', '', '', '', '', '']

# %%
for term in tfidf_vectorizer.vocabulary_.keys():
    terms[tfidf_vectorizer.vocabulary_[term]] = term
for topic_index in range(H.shape[0]):  # H.shape[0] is k
    top_indices = np.argsort(H[topic_index,:])[::-1][0:10]
    term_ranking = [terms[i] for i in top_indices]
    print("Topic {}: {}".format(topic_index, ", ".join(term_ranking)))
# Out:
# Topic 0: along, electronics, independent, lot, shop, one, location1, tube, transforming, ten
# Topic 1: location1, tube, ten, location2, min, direct, go, transforming, shop, price
# Topic 2: transforming, price, go, location1, tube, ten, shop, one, min, lot
# Topic 3: direct, location2, min, ten, tube, location1, transforming, shop, price, one
# Topic 4: location1, tube, transforming, ten, shop, price, one, min, lot, location2
# Topic 5: one, lot, shop, electronics, independent, along, tube, transforming, ten, price
# Topic 6: location1, tube, transforming, ten, shop, price, one, min, lot, location2
# Topic 7: along, lot, shop, independent, location1, electronics, one, tube, transforming, ten
# Topic 8: lot, independent, one, along, location1, shop, electronics, tube, transforming, ten
# Topic 9: one, location1, independent, shop, along, electronics, lot, tube, transforming, ten
# Topic 10: direct, location2, min, tube, ten, location1, transforming, shop, price, one
# Topic 11: electronics, one, location1, lot, along, shop, independent, tube, transforming, ten
# Topic 12: go, price, transforming, location1, tube, ten, shop, one, min, lot
# Topic 13: go, price, location1, transforming, tube, ten, shop, one, min, lot
# Topic 14: min, tube, ten, location1, direct, location2, transforming, shop, price, one

# %%
terms
# Out:
# ['along',
#  'direct',
#  'electronics',
#  'go',
#  'independent',
#  'location1',
#  'location2',
#  'lot',
#  'min',
#  'one',
#  'price',
#  'shop',
#  'ten',
#  'transforming',
#  'tube']
