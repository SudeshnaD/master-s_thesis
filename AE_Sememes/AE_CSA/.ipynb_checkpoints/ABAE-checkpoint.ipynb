# %%
asp_size_ft=['29', '30', '31', '32', '33', '34', '50', '51', '52', '53', '54', '40', '41', '42', '43', '44', '55', '56', '57', '58', '59', '45', '46', '47', '48', '49', '35', '36', '37', '38', '39']
avg_mean_ft=['0.2911617343172414', '0.29617770638', '0.29263915156774195', '0.290453919421875', '0.29239990571515145', '0.287040731932353', '0.27040400695', '0.2691845250725491', '0.2702280398153846', '0.270623952809434', '0.2683277234666666', 
'0.2754871491875', '0.2784192070146341', '0.27612309908809524', '0.2760926507744186', '0.27634411374999995', '0.2690242317345454', '0.2682397248946428', '0.2666485029666667', '0.2648529086086207', '0.2641745054118645', '0.27488519532888883', '0.27383425461304356', '0.2718231720297872', '0.27124235118750006', 
'0.2708423354408163', '0.28538885731142855', '0.28467047139444446', '0.28236572061351356', '0.28176075249210536', '0.28055297668974366']

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
asp_ft=[int(x) for x in asp_size_ft]
avg_ft=[float(x) for x in avg_mean_ft]
elbowft=[asp_ft,avg_ft]
elbowftdf=pd.DataFrame(elbowft)
elbowftdf=elbowftdf.T
elbowftdf.columns = ['K', 'Cosine similarity']
elbowftdf=elbowftdf.sort_values(by=['K'])

# %%
asp_size=['29', '30', '31', '32', '33', '34', '50', '51', '52', '53', '54', '40', '41', '42', '43', '44', '55', '56', '57', '58', '59', '45', '46', '47', '48', '49', '35', '36', '37', '38', '39']
avg_mean=['0.2911617343172414', '0.29617770638', '0.29263915156774195', '0.290453919421875', '0.29239990571515145', '0.287040731932353', '0.27040400695', '0.2691845250725491', '0.2702280398153846', '0.270623952809434', '0.2683277234666666', '0.2754871491875', '0.2784192070146341', '0.27612309908809524', '0.2760926507744186', '0.27634411374999995', '0.2690242317345454', '0.2682397248946428', '0.2666485029666667', '0.2648529086086207', '0.2641745054118645', '0.27488519532888883', '0.27383425461304356', '0.2718231720297872', '0.27124235118750006', '0.2708423354408163', '0.28538885731142855', '0.28467047139444446', '0.28236572061351356', '0.28176075249210536', '0.28055297668974366']

# %%
aspsize=[int(x) for x in asp_size]
avgmean=[float(x) for x in avg_mean]
elbow=[aspsize,avgmean]
elbowdf=pd.DataFrame(elbow)
elbowdf=elbowdf.T
elbowdf.columns = ['K', 'Cosine similarity']
elbowdf=elbowdf.sort_values(by=['K'])

# %%
elbow_pt_ft=pd.merge(elbowdf,elbowftdf,on='K')
print(elbow_pt_ft)
# Out:
#        K  Cosine similarity_x  Cosine similarity_y
# 0   29.0             0.291162             0.291162
# 1   30.0             0.296178             0.296178
# 2   31.0             0.292639             0.292639
# 3   32.0             0.290454             0.290454
# 4   33.0             0.292400             0.292400
# 5   34.0             0.287041             0.287041
# 6   35.0             0.285389             0.285389
# 7   36.0             0.284670             0.284670
# 8   37.0             0.282366             0.282366
# 9   38.0             0.281761             0.281761
# 10  39.0             0.280553             0.280553
# 11  40.0             0.275487             0.275487
# 12  41.0             0.278419             0.278419
# 13  42.0             0.276123             0.276123
# 14  43.0             0.276093             0.276093
# 15  44.0             0.276344             0.276344
# 16  45.0             0.274885             0.274885
# ...
